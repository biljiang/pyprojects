# %%
import pathlib as pl
import pandas as pd
import numpy as np
from datetime import datetime

# %%
'''
filepath=pl.Path('./data/mdc43403.dbf')
column_names=[
  'org_no',
  'tg_id',
  'data_date',
  'insert_time',
  'cons_id',
  'cons_sort_code',
  'cons_status_code',
  'poweroff_code',
  'mr_sect_no',
  'meter_id',
  'meter_run_state',
  'meter_sort_code',
  'meter_mfr',
  'run_cap',
  'contract_cap',
  'meter_bar_code',
  'wiring_mode',
  'mp_id',
  'mp_status_code',
  'mp_attr_code',
  'usage_type_code',
  'tmnl_bar_code',
  'tmnl_addr',
  'tmnl_type',
  'tmnl_status_code',
  'tmnl_mfr',
  'urban_rural_flag',
  'coll_obj_id',
  'dc_flag',
  'pq_total',
  'fc_gc_flag',
  'pap_r_flag',
  'rap_r_flag',
  'last_succ_date',
  'abnormal',
  'fail_day_sum',
  'data_src_flag',
  'tmnl_status',
  'tmnl_clock_flag',
  'meter_not_ai_flag',
  'meter_clock_flag',
  'meter_para_error_flag',
  'meter_succ_one_flag',
  'meter_succ_sec_flag',
  'meter_succ_three_flag',
  'meter_succ_four_flag',
  'tg_no',
  'tg_name',
  'cons_no',
  'cons_name',
  'meter_model',
  'tmnl_model',
  'cp_no',
  'comm_addr1',
  't_factor',
  'mp_level',
  'elec_addr',
  'mp_no',
  'mp_name',
  'if_read_flag',
  'run_state',
  'elec_type_code',
  'data_res_flag',
  'line_id',
  'line_name',
  'd_meter_type',
  'ps_date',
  'inst_date',
]
'''
# Out:
# "\nfilepath=pl.Path('./data/mdc43403.dbf')\ncolumn_names=[\n  'org_no',\n  'tg_id',\n  'data_date',\n  'insert_time',\n  'cons_id',\n  'cons_sort_code',\n  'cons_status_code',\n  'poweroff_code',\n  'mr_sect_no',\n  'meter_id',\n  'meter_run_state',\n  'meter_sort_code',\n  'meter_mfr',\n  'run_cap',\n  'contract_cap',\n  'meter_bar_code',\n  'wiring_mode',\n  'mp_id',\n  'mp_status_code',\n  'mp_attr_code',\n  'usage_type_code',\n  'tmnl_bar_code',\n  'tmnl_addr',\n  'tmnl_type',\n  'tmnl_status_code',\n  'tmnl_mfr',\n  'urban_rural_flag',\n  'coll_obj_id',\n  'dc_flag',\n  'pq_total',\n  'fc_gc_flag',\n  'pap_r_flag',\n  'rap_r_flag',\n  'last_succ_date',\n  'abnormal',\n  'fail_day_sum',\n  'data_src_flag',\n  'tmnl_status',\n  'tmnl_clock_flag',\n  'meter_not_ai_flag',\n  'meter_clock_flag',\n  'meter_para_error_flag',\n  'meter_succ_one_flag',\n  'meter_succ_sec_flag',\n  'meter_succ_three_flag',\n  'meter_succ_four_flag',\n  'tg_no',\n  'tg_name',\n  'cons_no',\n  'cons_name',\n  'meter_model',\n  'tmnl_model',\n  'cp_no',\n  'comm_addr1',\n  't_factor',\n  'mp_level',\n  'elec_addr',\n  'mp_no',\n  'mp_name',\n  'if_read_flag',\n  'run_state',\n  'elec_type_code',\n  'data_res_flag',\n  'line_id',\n  'line_name',\n  'd_meter_type',\n  'ps_date',\n  'inst_date',\n]\n"

# %%
#df= pd.read_csv(filepath,sep='\$\|', names=column_names, engine='python',nrows=50000)

# %%
#import psycopg2

#con= psycopg2.connect(database="cqbus",user="gpadmin",password="gpadmin",host="192.168.0.93",port="5432")

# %%
#df1 = pd.read_sql('select * from cqbus2017 limit 10;', con=con)
#df1

# %%
#con.close()

# %%
import psycopg2

con= psycopg2.connect(database="sgcc_hn",user="gpadmin",password="gpadmin",host="192.168.0.93",port="5432")

# %%
cur = con.cursor()
cur.execute("set search_path to mpac;")

# %%
#df1 = pd.read_sql('select * from train_data limit 10;', con=con)
#df1

# %%
df = pd.read_sql('select * from train_data;', con=con)
con.close()

# %%
df[:10]
# Out:
#            meter_id pap_r_flag wiring_mode     meter_mfr d_meter_type  \
# 0  2012000011164381          1           1    北京博纳电子有限公司           28
# 1  8000000046734176          1           1          None           28
# 2  8000000050724631          1           3  青岛乾程电子科技有限公司           28
# 3  8000000057723325          1           1  浙江八达电子仪表有限公司           28
# 4  8000000049042786          1           1  宁波三星电气股份有限公司           28
# 5  8000000046740791          1           1          None           28
# 6  8000000049042607          1           1  宁波三星电气股份有限公司           28
# 7  2013000015778303          1           1    江苏林洋电子有限公司           28
# 8  8000000052883644          1           1    长沙威胜电子有限公司           28
# 9  2012000011170447          1           1    北京博纳电子有限公司           28
#
#      meter_model tmnl_mfr    tmnl_model   inst_date manufacturer comm_mode  \
# 0    07单相居民表(加密)       24  低压集中器(376.1)  2012-08-18        10021        03
# 1   07_2013单相居民表    00073  低压集中器(376.1)  2015-08-24        00420        03
# 2  07_2013国标多功能表       31  低压集中器(376.1)  2016-09-24        00604        08
# 3   07_2013单相居民表    00758   水电气热一体化采集终端  2017-07-06        01064        03
# 4   07_2013单相居民表       31  低压集中器(376.1)  2016-04-30        00578        03
# 5   07_2013单相居民表       24  低压集中器(376.1)  2015-09-01        00420        03
# 6   07_2013单相居民表       31  低压集中器(376.1)  2016-05-13        00578        03
# 7    07单相居民表(加密)       31  低压集中器(376.1)  2014-05-17         None      None
# 8   07_2013单相居民表    10001  低压集中器(376.1)  2016-08-24        00924        03
# 9    07单相居民表(加密)       06  低压集中器(376.1)  2012-09-24        10021        03
#
#   comm_prot_code  rs485_route_qty
# 0             02              1.0
# 1             05              1.0
# 2             05              2.0
# 3             05              1.0
# 4             05              1.0
# 5             05              1.0
# 6             05              1.0
# 7           None              NaN
# 8             05              1.0
# 9             02              1.0

# %%
df.isnull().sum() # check null
# Out:
# meter_id                0
# pap_r_flag              0
# wiring_mode             0
# meter_mfr          210528
# d_meter_type            0
# meter_model          3706
# tmnl_mfr            97912
# tmnl_model           3706
# inst_date               0
# manufacturer       604361
# comm_mode          604427
# comm_prot_code     605087
# rs485_route_qty    604691
# dtype: int64

# %%
import matplotlib.pylab as plt 
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report

# %%
df=df.drop('manufacturer',axis=1)
df=df.dropna()

# %%
#df.inst_date.apply(lambda x: datetime.strptime(str(x),"%Y-%m-%d"))
#df.inst_date.apply(lambda x:x.year)
df["inst_date"]=df.inst_date.apply(lambda x: x.year)

# %%
df["inst_date"]=df.inst_date.apply(str)
df["rs485_route_qty"]=df.rs485_route_qty.apply(str)

# %%
#shuffler= np.random.permutation(len(df))
#df = df.take(shuffler)

# %%
df.groupby("pap_r_flag").count()
# Out:
#             meter_id  wiring_mode  meter_mfr  d_meter_type  meter_model  \
# pap_r_flag
# 0              14814        14814      14814         14814        14814
# 1            2528364      2528364    2528364       2528364      2528364
#
#             tmnl_mfr  tmnl_model  inst_date  comm_mode  comm_prot_code  \
# pap_r_flag
# 0              14814       14814      14814      14814           14814
# 1            2528364     2528364    2528364    2528364         2528364
#
#             rs485_route_qty
# pap_r_flag
# 0                     14814
# 1                   2528364

# %%
df.groupby("meter_mfr").count()
# Out:
#                   meter_id  pap_r_flag  wiring_mode  d_meter_type  \
# meter_mfr
# 上海金陵智能电表有限公司        126769      126769       126769        126769
# 中国振华电子集团百智科技有限公司      1761        1761         1761          1761
# 中国晨泰电器仪表有限公司          4805        4805         4805          4805
# 中电装备山东电子有限公司         34443       34443        34443         34443
# 北京博纳电子有限公司          113379      113379       113379        113379
# 北京煜邦电力技术有限公司         30133       30133        30133         30133
# 南京能瑞自动化设备股份有限公司      74930       74930        74930         74930
# 宁夏隆基宁光仪表有限公司        256686      256686       256686        256686
# 宁波三星电气股份有限公司        260247      260247       260247        260247
# 安徽南瑞中天电力电子有限公司       25558       25558        25558         25558
# 怀化建南机器厂有限公司             12          12           12            12
# 杭州海兴电力科技有限公司        229912      229912       229912        229912
# 杭州炬华科技股份有限公司        327738      327738       327738        327738
# 杭州西力电能表制造有限公司           42          42           42            42
# 武汉盛帆电子股份有限公司          9679        9679         9679          9679
# 江苏林洋电子有限公司          307719      307719       307719        307719
# 江苏盛德电子仪表有限公司          6002        6002         6002          6002
# 江苏西欧电子有限公司           36996       36996        36996         36996
# 河南许继仪表有限公司           21562       21562        21562         21562
# 浙江八达电子仪表有限公司         55987       55987        55987         55987
# 浙江华立仪表集团股份有限责任公司     22254       22254        22254         22254
# 浙江恒业电子有限公司            2862        2862         2862          2862
# 浙江晨泰电器仪表有限公司         10089       10089        10089         10089
# 浙江正泰电气股份有限公司          7339        7339         7339          7339
# 深圳市泰瑞捷电子有限公司        145331      145331       145331        145331
# 深圳市科陆电子科技股份有限公司       8333        8333         8333          8333
# 深圳市龙电电气有限公司          78286       78286        78286         78286
# 深圳开发科技股份有限公司           507         507          507           507
# 深圳浩宁达电能仪表制造有限公司      47695       47695        47695         47695
# 深圳长城开发科技股份有限公司       41718       41718        41718         41718
# 溧阳市华鹏电力仪表有限公司         5364        5364         5364          5364
# 石家庄科林自动化有限公司         98101       98101        98101         98101
# 长沙威胜电子有限公司          150759      150759       150759        150759
# 青岛乾程电子科技有限公司           180         180          180           180
#
#                   meter_model  tmnl_mfr  tmnl_model  inst_date  comm_mode  \
# meter_mfr
# 上海金陵智能电表有限公司           126769    126769      126769     126769     126769
# 中国振华电子集团百智科技有限公司         1761      1761        1761       1761       1761
# 中国晨泰电器仪表有限公司             4805      4805        4805       4805       4805
# 中电装备山东电子有限公司            34443     34443       34443      34443      34443
# 北京博纳电子有限公司             113379    113379      113379     113379     113379
# 北京煜邦电力技术有限公司            30133     30133       30133      30133      30133
# 南京能瑞自动化设备股份有限公司         74930     74930       74930      74930      74930
# 宁夏隆基宁光仪表有限公司           256686    256686      256686     256686     256686
# 宁波三星电气股份有限公司           260247    260247      260247     260247     260247
# 安徽南瑞中天电力电子有限公司          25558     25558       25558      25558      25558
# 怀化建南机器厂有限公司                12        12          12         12         12
# 杭州海兴电力科技有限公司           229912    229912      229912     229912     229912
# 杭州炬华科技股份有限公司           327738    327738      327738     327738     327738
# 杭州西力电能表制造有限公司              42        42          42         42         42
# 武汉盛帆电子股份有限公司             9679      9679        9679       9679       9679
# 江苏林洋电子有限公司             307719    307719      307719     307719     307719
# 江苏盛德电子仪表有限公司             6002      6002        6002       6002       6002
# 江苏西欧电子有限公司              36996     36996       36996      36996      36996
# 河南许继仪表有限公司              21562     21562       21562      21562      21562
# 浙江八达电子仪表有限公司            55987     55987       55987      55987      55987
# 浙江华立仪表集团股份有限责任公司        22254     22254       22254      22254      22254
# 浙江恒业电子有限公司               2862      2862        2862       2862       2862
# 浙江晨泰电器仪表有限公司            10089     10089       10089      10089      10089
# 浙江正泰电气股份有限公司             7339      7339        7339       7339       7339
# 深圳市泰瑞捷电子有限公司           145331    145331      145331     145331     145331
# 深圳市科陆电子科技股份有限公司          8333      8333        8333       8333       8333
# 深圳市龙电电气有限公司             78286     78286       78286      78286      78286
# 深圳开发科技股份有限公司              507       507         507        507        507
# 深圳浩宁达电能仪表制造有限公司         47695     47695       47695      47695      47695
# 深圳长城开发科技股份有限公司          41718     41718       41718      41718      41718
# 溧阳市华鹏电力仪表有限公司            5364      5364        5364       5364       5364
# 石家庄科林自动化有限公司            98101     98101       98101      98101      98101
# 长沙威胜电子有限公司             150759    150759      150759     150759     150759
# 青岛乾程电子科技有限公司              180       180         180        180        180
#
#                   comm_prot_code  rs485_route_qty
# meter_mfr
# 上海金陵智能电表有限公司              126769           126769
# 中国振华电子集团百智科技有限公司            1761             1761
# 中国晨泰电器仪表有限公司                4805             4805
# 中电装备山东电子有限公司               34443            34443
# 北京博纳电子有限公司                113379           113379
# 北京煜邦电力技术有限公司               30133            30133
# 南京能瑞自动化设备股份有限公司            74930            74930
# 宁夏隆基宁光仪表有限公司              256686           256686
# 宁波三星电气股份有限公司              260247           260247
# 安徽南瑞中天电力电子有限公司             25558            25558
# 怀化建南机器厂有限公司                   12               12
# 杭州海兴电力科技有限公司              229912           229912
# 杭州炬华科技股份有限公司              327738           327738
# 杭州西力电能表制造有限公司                 42               42
# 武汉盛帆电子股份有限公司                9679             9679
# 江苏林洋电子有限公司                307719           307719
# 江苏盛德电子仪表有限公司                6002             6002
# 江苏西欧电子有限公司                 36996            36996
# 河南许继仪表有限公司                 21562            21562
# 浙江八达电子仪表有限公司               55987            55987
# 浙江华立仪表集团股份有限责任公司           22254            22254
# 浙江恒业电子有限公司                  2862             2862
# 浙江晨泰电器仪表有限公司               10089            10089
# 浙江正泰电气股份有限公司                7339             7339
# 深圳市泰瑞捷电子有限公司              145331           145331
# 深圳市科陆电子科技股份有限公司             8333             8333
# 深圳市龙电电气有限公司                78286            78286
# 深圳开发科技股份有限公司                 507              507
# 深圳浩宁达电能仪表制造有限公司            47695            47695
# 深圳长城开发科技股份有限公司             41718            41718
# 溧阳市华鹏电力仪表有限公司               5364             5364
# 石家庄科林自动化有限公司               98101            98101
# 长沙威胜电子有限公司                150759           150759
# 青岛乾程电子科技有限公司                 180              180

# %%
df.columns
# Out:
# Index(['meter_id', 'pap_r_flag', 'wiring_mode', 'meter_mfr', 'd_meter_type',
#        'meter_model', 'tmnl_mfr', 'tmnl_model', 'inst_date', 'comm_mode',
#        'comm_prot_code', 'rs485_route_qty'],
#       dtype='object')

# %%
df_dummies = pd.get_dummies(df[['wiring_mode', 'meter_mfr', 'd_meter_type',
       'meter_model', 'tmnl_mfr', 'tmnl_model', 'inst_date',
       'comm_mode', 'comm_prot_code', 'rs485_route_qty']])

# %%
df_dummies.columns
# Out:
# Index(['wiring_mode_1', 'wiring_mode_3', 'meter_mfr_上海金陵智能电表有限公司',
#        'meter_mfr_中国振华电子集团百智科技有限公司', 'meter_mfr_中国晨泰电器仪表有限公司',
#        'meter_mfr_中电装备山东电子有限公司', 'meter_mfr_北京博纳电子有限公司',
#        'meter_mfr_北京煜邦电力技术有限公司', 'meter_mfr_南京能瑞自动化设备股份有限公司',
#        'meter_mfr_宁夏隆基宁光仪表有限公司',
#        ...
#        'inst_date_2017', 'inst_date_2018', 'comm_mode_02', 'comm_mode_03',
#        'comm_mode_08', 'comm_prot_code_02', 'comm_prot_code_05',
#        'rs485_route_qty_0.0', 'rs485_route_qty_1.0', 'rs485_route_qty_2.0'],
#       dtype='object', length=113)

# %%
Y=1-df.pap_r_flag.apply(int)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df_dummies,Y,test_size=0.3,random_state=0)

# %%
#classifier = LogisticRegression(random_state=4,class_weight="balanced") 
classifier = LogisticRegression(random_state=4) 
classifier.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=4,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
Y_prob = classifier.predict_proba(X_test)

# %%
import pylab
pylab.rcParams['figure.figsize'] = (12.0, 4.0)

# %%
plt.hist(Y_prob[:,0],bins=30,color='red',alpha=0.3)
plt.hist(Y_prob[:,1],bins=30,color='blue',alpha=0.5)
# Out:
# (array([7.4673e+04, 7.3148e+04, 1.5490e+04, 2.8426e+04, 3.0570e+04,
#         2.9813e+04, 3.2092e+04, 2.2155e+04, 1.5503e+04, 1.7819e+04,
#         2.4990e+04, 2.5543e+04, 2.4212e+04, 3.2928e+04, 6.2768e+04,
#         1.8023e+04, 3.0969e+04, 2.2443e+04, 3.2242e+04, 3.0500e+04,
#         2.9354e+04, 2.5915e+04, 2.2138e+04, 7.9730e+03, 1.3840e+04,
#         1.7761e+04, 7.0500e+02, 8.0300e+02, 1.1800e+02, 4.0000e+01]),
#  array([7.19973950e-05, 3.31814930e-02, 6.62909887e-02, 9.94004843e-02,
#         1.32509980e-01, 1.65619476e-01, 1.98728971e-01, 2.31838467e-01,
#         2.64947963e-01, 2.98057458e-01, 3.31166954e-01, 3.64276450e-01,
#         3.97385945e-01, 4.30495441e-01, 4.63604937e-01, 4.96714432e-01,
#         5.29823928e-01, 5.62933423e-01, 5.96042919e-01, 6.29152415e-01,
#         6.62261910e-01, 6.95371406e-01, 7.28480902e-01, 7.61590397e-01,
#         7.94699893e-01, 8.27809389e-01, 8.60918884e-01, 8.94028380e-01,
#         9.27137876e-01, 9.60247371e-01, 9.93356867e-01]),
#  <a list of 30 Patch objects>)

# %%
Y_prob
# Out:
# array([[0.83319653, 0.16680347],
#        [0.62484763, 0.37515237],
#        [0.33366441, 0.66633559],
#        ...,
#        [0.50931325, 0.49068675],
#        [0.96918288, 0.03081712],
#        [0.50931325, 0.49068675]])

# %%
Y_prob.shape
# Out:
# (762954, 2)

# %%
Y_prob_df = pd.DataFrame(Y_prob,columns=["p_succ","p_unsucc"])

# %%
Y_prob_df.quantile(0.95)
# Out:
# p_succ      0.991495
# p_unsucc    0.775108
# Name: 0.95, dtype: float64

# %%
#df.inst_date.apply(lambda x: datetime.strptime(str(x),"%Y-%m-%d"))
#df.inst_date.apply(lambda x:x.year)

# %%
Y_prob[:,1]
# Out:
# array([0.16680347, 0.37515237, 0.66633559, ..., 0.49068675, 0.03081712,
#        0.49068675])

# %%
result_ana=X_test.join(Y_prob_df)

# %%
result_ana["Y"]=Y_test

# %%
result_ana["ProbCat"]=pd.qcut(Y_prob_df.p_unsucc,20)

# %%
rlt_1=result_ana.groupby("ProbCat").sum()

# %%
rlt_2=rlt_1/rlt_1.sum()
rlt_2
# Out:
#                      wiring_mode_1  wiring_mode_3  meter_mfr_上海金陵智能电表有限公司  \
# ProbCat
# (-0.000928, 0.0085]       0.060204       0.061538                0.058890
# (0.0085, 0.0335]          0.040111       0.037547                0.034343
# (0.0335, 0.041]           0.049518       0.045186                0.049431
# (0.041, 0.0734]           0.050313       0.050888                0.048981
# (0.0734, 0.13]            0.050486       0.051318                0.053710
# (0.13, 0.167]             0.049412       0.052179                0.050783
# (0.167, 0.206]            0.050337       0.050242                0.049431
# (0.206, 0.26]             0.050095       0.048951                0.047179
# (0.26, 0.341]             0.051691       0.052394                0.049544
# (0.341, 0.385]            0.048518       0.048198                0.051008
# (0.385, 0.434]            0.054200       0.055299                0.053260
# (0.434, 0.484]            0.050735       0.051533                0.051233
# (0.484, 0.491]            0.050207       0.045939                0.053823
# (0.491, 0.538]            0.064687       0.059602                0.062380
# (0.538, 0.575]            0.031487       0.031415                0.031078
# (0.575, 0.626]            0.049003       0.050350                0.055174
# (0.626, 0.673]            0.051095       0.054868                0.051120
# (0.673, 0.716]            0.054181       0.056159                0.052922
# (0.716, 0.775]            0.047283       0.049489                0.048080
# (0.775, 0.993]            0.046438       0.046907                0.047630
#
#                      meter_mfr_中国振华电子集团百智科技有限公司  meter_mfr_中国晨泰电器仪表有限公司  \
# ProbCat
# (-0.000928, 0.0085]                    0.084746                0.043624
# (0.0085, 0.0335]                       0.033898                0.070470
# (0.0335, 0.041]                        0.042373                0.033557
# (0.041, 0.0734]                        0.067797                0.050336
# (0.0734, 0.13]                         0.059322                0.033557
# (0.13, 0.167]                          0.050847                0.033557
# (0.167, 0.206]                         0.067797                0.036913
# (0.206, 0.26]                          0.050847                0.070470
# (0.26, 0.341]                          0.059322                0.043624
# (0.341, 0.385]                         0.067797                0.046980
# (0.385, 0.434]                         0.033898                0.070470
# (0.434, 0.484]                         0.016949                0.067114
# (0.484, 0.491]                         0.033898                0.043624
# (0.491, 0.538]                         0.050847                0.063758
# (0.538, 0.575]                         0.042373                0.020134
# (0.575, 0.626]                         0.042373                0.067114
# (0.626, 0.673]                         0.033898                0.046980
# (0.673, 0.716]                         0.050847                0.053691
# (0.716, 0.775]                         0.025424                0.043624
# (0.775, 0.993]                         0.084746                0.060403
#
#                      meter_mfr_中电装备山东电子有限公司  meter_mfr_北京博纳电子有限公司  \
# ProbCat
# (-0.000928, 0.0085]                0.059984              0.054777
# (0.0085, 0.0335]                   0.033279              0.042896
# (0.0335, 0.041]                    0.048891              0.049025
# (0.041, 0.0734]                    0.051767              0.049650
# (0.0734, 0.13]                     0.050534              0.052401
# (0.13, 0.167]                      0.048480              0.048024
# (0.167, 0.206]                     0.041495              0.052151
# (0.206, 0.26]                      0.053410              0.048149
# (0.26, 0.341]                      0.047658              0.053152
# (0.341, 0.385]                     0.048891              0.053777
# (0.385, 0.434]                     0.051767              0.059280
# (0.434, 0.484]                     0.047658              0.053027
# (0.484, 0.491]                     0.050945              0.043647
# (0.491, 0.538]                     0.071898              0.065908
# (0.538, 0.575]                     0.034511              0.031766
# (0.575, 0.626]                     0.050945              0.048399
# (0.626, 0.673]                     0.054232              0.051151
# (0.673, 0.716]                     0.062038              0.052026
# (0.716, 0.775]                     0.051356              0.047274
# (0.775, 0.993]                     0.040263              0.043522
#
#                      meter_mfr_北京煜邦电力技术有限公司  meter_mfr_南京能瑞自动化设备股份有限公司  \
# ProbCat
# (-0.000928, 0.0085]                0.062967                   0.059354
# (0.0085, 0.0335]                   0.028282                   0.039503
# (0.0335, 0.041]                    0.048559                   0.045117
# (0.041, 0.0734]                    0.054963                   0.056347
# (0.0734, 0.13]                     0.046958                   0.051935
# (0.13, 0.167]                      0.041622                   0.051735
# (0.167, 0.206]                     0.056564                   0.054341
# (0.206, 0.26]                      0.053895                   0.048526
# (0.26, 0.341]                      0.049626                   0.047524
# (0.341, 0.385]                     0.050160                   0.040305
# (0.385, 0.434]                     0.050694                   0.049529
# (0.434, 0.484]                     0.050694                   0.050732
# (0.484, 0.491]                     0.051227                   0.049328
# (0.491, 0.538]                     0.061366                   0.070383
# (0.538, 0.575]                     0.030416                   0.030479
# (0.575, 0.626]                     0.043757                   0.044917
# (0.626, 0.673]                     0.055496                   0.050331
# (0.673, 0.716]                     0.058698                   0.061961
# (0.716, 0.775]                     0.044824                   0.049930
# (0.775, 0.993]                     0.059232                   0.047724
#
#                      meter_mfr_宁夏隆基宁光仪表有限公司    ...     comm_mode_03  \
# ProbCat                                        ...
# (-0.000928, 0.0085]                0.059845    ...         0.060337
# (0.0085, 0.0335]                   0.039540    ...         0.039978
# (0.0335, 0.041]                    0.047609    ...         0.049348
# (0.041, 0.0734]                    0.051082    ...         0.050524
# (0.0734, 0.13]                     0.049906    ...         0.050395
# (0.13, 0.167]                      0.051456    ...         0.049539
# (0.167, 0.206]                     0.050708    ...         0.050278
# (0.206, 0.26]                      0.049746    ...         0.050075
# (0.26, 0.341]                      0.050601    ...         0.051695
# (0.341, 0.385]                     0.048998    ...         0.048491
# (0.385, 0.434]                     0.053647    ...         0.054245
# (0.434, 0.484]                     0.050655    ...         0.050684
# (0.484, 0.491]                     0.049426    ...         0.050124
# (0.491, 0.538]                     0.066898    ...         0.064532
# (0.538, 0.575]                     0.030510    ...         0.031397
# (0.575, 0.626]                     0.051082    ...         0.048941
# (0.626, 0.673]                     0.051135    ...         0.051208
# (0.673, 0.716]                     0.054876    ...         0.054331
# (0.716, 0.775]                     0.046594    ...         0.047463
# (0.775, 0.993]                     0.045685    ...         0.046416
#
#                      comm_mode_08  comm_prot_code_02  comm_prot_code_05  \
# ProbCat
# (-0.000928, 0.0085]      0.057880           0.058980           0.060868
# (0.0085, 0.0335]         0.039308           0.041714           0.039177
# (0.0335, 0.041]          0.046700           0.050187           0.048868
# (0.041, 0.0734]          0.049405           0.051237           0.049937
# (0.0734, 0.13]           0.052470           0.049438           0.051031
# (0.13, 0.167]            0.051208           0.048913           0.049860
# (0.167, 0.206]           0.050307           0.050056           0.050458
# (0.206, 0.26]            0.049405           0.050300           0.049911
# (0.26, 0.341]            0.050487           0.052306           0.051467
# (0.341, 0.385]           0.049225           0.049588           0.048005
# (0.385, 0.434]           0.056076           0.056337           0.053313
# (0.434, 0.484]           0.053913           0.051125           0.050620
# (0.484, 0.491]           0.045438           0.048144           0.050808
# (0.491, 0.538]           0.058601           0.063873           0.064654
# (0.538, 0.575]           0.035701           0.030596           0.031887
# (0.575, 0.626]           0.053191           0.049250           0.048997
# (0.626, 0.673]           0.054093           0.051200           0.051347
# (0.673, 0.716]           0.053191           0.053543           0.054629
# (0.716, 0.775]           0.049405           0.046813           0.047672
# (0.775, 0.993]           0.043996           0.046400           0.046493
#
#                      rs485_route_qty_0.0  rs485_route_qty_1.0  \
# ProbCat
# (-0.000928, 0.0085]             0.065388             0.060063
# (0.0085, 0.0335]                0.034692             0.040247
# (0.0335, 0.041]                 0.047642             0.049467
# (0.041, 0.0734]                 0.044444             0.050550
# (0.0734, 0.13]                  0.052118             0.050382
# (0.13, 0.167]                   0.045883             0.049585
# (0.167, 0.206]                  0.046523             0.050469
# (0.206, 0.26]                   0.053557             0.049903
# (0.26, 0.341]                   0.050839             0.051839
# (0.341, 0.385]                  0.048122             0.048558
# (0.385, 0.434]                  0.055635             0.054043
# (0.434, 0.484]                  0.057234             0.050488
# (0.484, 0.491]                  0.050679             0.050015
# (0.491, 0.538]                  0.064269             0.064545
# (0.538, 0.575]                  0.032134             0.031463
# (0.575, 0.626]                  0.050839             0.048982
# (0.626, 0.673]                  0.054197             0.051098
# (0.673, 0.716]                  0.052278             0.054447
# (0.716, 0.775]                  0.045244             0.047419
# (0.775, 0.993]                  0.048281             0.046435
#
#                      rs485_route_qty_2.0    p_succ  p_unsucc         Y
# ProbCat
# (-0.000928, 0.0085]             0.060965  0.094853  0.001054  0.059980
# (0.0085, 0.0335]                0.036695  0.062077  0.002108  0.042281
# (0.0335, 0.041]                 0.043629  0.074966  0.005289  0.056047
# (0.041, 0.0734]                 0.051430  0.075573  0.007133  0.050147
# (0.0734, 0.13]                  0.054608  0.071793  0.014117  0.060964
# (0.13, 0.167]                   0.055186  0.066400  0.020725  0.061947
# (0.167, 0.206]                  0.050852  0.064357  0.026311  0.046214
# (0.206, 0.26]                   0.049697  0.060437  0.032212  0.053097
# (0.26, 0.341]                   0.048252  0.057183  0.042388  0.048181
# (0.341, 0.385]                  0.046518  0.048900  0.047817  0.044248
# (0.385, 0.434]                  0.061832  0.050467  0.060755  0.055064
# (0.434, 0.484]                  0.052586  0.043568  0.063128  0.040315
# (0.484, 0.491]                  0.046807  0.040332  0.066489  0.054081
# (0.491, 0.538]                  0.058365  0.048944  0.090899  0.050147
# (0.538, 0.575]                  0.031205  0.021860  0.047965  0.035398
# (0.575, 0.626]                  0.050274  0.031097  0.079871  0.038348
# (0.626, 0.673]                  0.055475  0.028792  0.089854  0.055064
# (0.673, 0.716]                  0.050563  0.025958  0.102813  0.047198
# (0.716, 0.775]                  0.050563  0.019289  0.095556  0.052114
# (0.775, 0.993]                  0.044496  0.013153  0.103518  0.049164
#
# [20 rows x 116 columns]

# %%
rlt_2.iloc[19]
# Out:
# wiring_mode_1                    0.046438
# wiring_mode_3                    0.046907
# meter_mfr_上海金陵智能电表有限公司           0.047630
# meter_mfr_中国振华电子集团百智科技有限公司       0.084746
# meter_mfr_中国晨泰电器仪表有限公司           0.060403
# meter_mfr_中电装备山东电子有限公司           0.040263
# meter_mfr_北京博纳电子有限公司             0.043522
# meter_mfr_北京煜邦电力技术有限公司           0.059232
# meter_mfr_南京能瑞自动化设备股份有限公司        0.047724
# meter_mfr_宁夏隆基宁光仪表有限公司           0.045685
# meter_mfr_宁波三星电气股份有限公司           0.047224
# meter_mfr_安徽南瑞中天电力电子有限公司         0.049296
# meter_mfr_怀化建南机器厂有限公司                 NaN
# meter_mfr_杭州海兴电力科技有限公司           0.046190
# meter_mfr_杭州炬华科技股份有限公司           0.047684
# meter_mfr_杭州西力电能表制造有限公司          1.000000
# meter_mfr_武汉盛帆电子股份有限公司           0.057895
# meter_mfr_江苏林洋电子有限公司             0.046170
# meter_mfr_江苏盛德电子仪表有限公司           0.041363
# meter_mfr_江苏西欧电子有限公司             0.047267
# meter_mfr_河南许继仪表有限公司             0.042135
# meter_mfr_浙江八达电子仪表有限公司           0.042513
# meter_mfr_浙江华立仪表集团股份有限责任公司       0.043819
# meter_mfr_浙江恒业电子有限公司             0.031579
# meter_mfr_浙江晨泰电器仪表有限公司           0.059190
# meter_mfr_浙江正泰电气股份有限公司           0.042435
# meter_mfr_深圳市泰瑞捷电子有限公司           0.046423
# meter_mfr_深圳市科陆电子科技股份有限公司        0.041667
# meter_mfr_深圳市龙电电气有限公司            0.042891
# meter_mfr_深圳开发科技股份有限公司           0.000000
#                                    ...
# tmnl_model_低压集中器(1376.1)         0.050734
# tmnl_model_低压集中器(1376.1)2        0.000000
# tmnl_model_低压集中器(1376.1)华立       0.125000
# tmnl_model_低压集中器(376.1)          0.046256
# tmnl_model_低压集中器(376.1)2         0.111111
# tmnl_model_低压集中器(376.1)华立        0.128205
# tmnl_model_低压集中器(面向对象698.45)     0.027174
# tmnl_model_新低压集中器(面向对象698.45)    0.044481
# tmnl_model_水电气热一体化采集终端           0.052604
# inst_date_2009                   0.000000
# inst_date_2010                   0.000000
# inst_date_2011                   0.046386
# inst_date_2012                   0.047067
# inst_date_2013                   0.045365
# inst_date_2014                   0.045990
# inst_date_2015                   0.046476
# inst_date_2016                   0.047214
# inst_date_2017                   0.046588
# inst_date_2018                   0.045691
# comm_mode_02                     0.055195
# comm_mode_03                     0.046416
# comm_mode_08                     0.043996
# comm_prot_code_02                0.046400
# comm_prot_code_05                0.046493
# rs485_route_qty_0.0              0.048281
# rs485_route_qty_1.0              0.046435
# rs485_route_qty_2.0              0.044496
# p_succ                           0.013153
# p_unsucc                         0.103518
# Y                                0.049164
# Name: (0.775, 0.993], Length: 116, dtype: float64

# %%
result_ana.columns
# Out:
# Index(['wiring_mode_1', 'wiring_mode_3', 'meter_mfr_上海金陵智能电表有限公司',
#        'meter_mfr_中国振华电子集团百智科技有限公司', 'meter_mfr_中国晨泰电器仪表有限公司',
#        'meter_mfr_中电装备山东电子有限公司', 'meter_mfr_北京博纳电子有限公司',
#        'meter_mfr_北京煜邦电力技术有限公司', 'meter_mfr_南京能瑞自动化设备股份有限公司',
#        'meter_mfr_宁夏隆基宁光仪表有限公司',
#        ...
#        'comm_mode_08', 'comm_prot_code_02', 'comm_prot_code_05',
#        'rs485_route_qty_0.0', 'rs485_route_qty_1.0', 'rs485_route_qty_2.0',
#        'p_unsucc', 'p_succ', 'Y', 'ProbCat'],
#       dtype='object', length=117)

# %%
result_ana.Y
# Out:
# 379860     0
# 267570     0
# 1274305    0
# 3028214    0
# 708132     0
# 1441255    0
# 435494     0
# 321917     0
# 1284828    0
# 982134     0
# 2481479    0
# 14647      0
# 2076299    0
# 2122893    0
# 2658954    0
# 843286     0
# 2414621    0
# 1483166    0
# 1511317    0
# 1975956    0
# 2499637    0
# 120712     0
# 2028508    0
# 1243284    0
# 97676      0
# 3028869    0
# 2242958    0
# 2580803    0
# 1582685    0
# 21494      0
#           ..
# 2006387    0
# 329287     0
# 714512     0
# 2459183    0
# 3166350    0
# 269223     0
# 507943     0
# 2024691    0
# 1491715    0
# 922943     0
# 157973     0
# 1131674    0
# 720731     0
# 1023264    0
# 537896     0
# 1601594    0
# 2543117    0
# 761452     0
# 3319922    0
# 2910079    0
# 718323     0
# 3167265    0
# 2547489    0
# 2721194    0
# 1334207    0
# 31542      0
# 1484293    0
# 2022736    0
# 839161     0
# 877832     0
# Name: Y, Length: 762954, dtype: int64

# %%
pd.qcut?
# Out:
# Signature: pd.qcut(x, q, labels=None, retbins=False, precision=3, duplicates='raise')
# Docstring:
# Quantile-based discretization function. Discretize variable into
# equal-sized buckets based on rank or based on sample quantiles. For example
# 1000 values for 10 quantiles would produce a Categorical object indicating
# quantile membership for each data point.
#
# Parameters
# ----------
# x : 1d ndarray or Series
# q : integer or array of quantiles
#     Number of quantiles. 10 for deciles, 4 for quartiles, etc. Alternately
#     array of quantiles, e.g. [0, .25, .5, .75, 1.] for quartiles
# labels : array or boolean, default None
#     Used as labels for the resulting bins. Must be of the same length as
#     the resulting bins. If False, return only integer indicators of the
#     bins.
# retbins : bool, optional
#     Whether to return the (bins, labels) or not. Can be useful if bins
#     is given as a scalar.
# precision : int, optional
#     The precision at which to store and display the bins labels
# duplicates : {default 'raise', 'drop'}, optional
#     If bin edges are not unique, raise ValueError or drop non-uniques.
#
#     .. versionadded:: 0.20.0
#
# Returns
# -------
# out : Categorical or Series or array of integers if labels is False
#     The return type (Categorical or Series) depends on the input: a Series
#     of type category if input is a Series else Categorical. Bins are
#     represented as categories when categorical data is returned.
# bins : ndarray of floats
#     Returned only if `retbins` is True.
#
# Notes
# -----
# Out of bounds values will be NA in the resulting Categorical object
#
# Examples
# --------
# >>> pd.qcut(range(5), 4)
# ... # doctest: +ELLIPSIS
# [(-0.001, 1.0], (-0.001, 1.0], (1.0, 2.0], (2.0, 3.0], (3.0, 4.0]]
# Categories (4, interval[float64]): [(-0.001, 1.0] < (1.0, 2.0] ...
#
# >>> pd.qcut(range(5), 3, labels=["good", "medium", "bad"])
# ... # doctest: +SKIP
# [good, good, medium, bad, bad]
# Categories (3, object): [good < medium < bad]
#
# >>> pd.qcut(range(5), 4, labels=False)
# array([0, 0, 1, 2, 3])
# File:      ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/tile.py
# Type:      function
