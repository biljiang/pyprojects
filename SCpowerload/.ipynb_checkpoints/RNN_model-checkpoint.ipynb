# %%
from datetime import datetime,date,time
import pandas as pd
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
from pandas.tseries.offsets import Day

import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 4
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv("四川台区日负荷.csv")
df.序列 = df.序列.apply(lambda x: datetime.strptime(x,"%Y-%m-%d %H:%M:%S"))
df=df.set_index("序列")
df_series=df["2017-8-3":"2017-11-23"]# 11-24,25 and 12-11,12 do not have correct numbers. so dropped

# %%
#TIMESTEPS = 672

# %%
#df["date"]=df.序列.apply(lambda x: x.date())

# %%
#df["time"]=df.序列.apply(lambda x: x.time())

# %%
#df_reshaped=df.pivot("date","time","值")
#df_reshaped = df_reshaped.dropna()

# %%
#tr=df[df.index<datetime(2017,12,15)]
#te=df[df.index>=datetime(2017,12,15)]

# %%
start_date=datetime(2017,8,5)
s_date=start_date.date().strftime("%Y-%m-%d")
e_date=(start_date+Day(7)).date().strftime("%Y-%m-%d")
t_date=(start_date+Day(8)).date().strftime("%Y-%m-%d")
t_date
# Out:
# '2017-08-13'

# %%
Max= df_series.max()
Min= df_series.min()

# %%
X_series = (df_series-Min)/(Max-Min)
Xh=X_series.resample("H").mean()
Xh[s_date:e_date].plot()
plt.show()

# %%
Xh=X_series.resample("H").mean()

# %%
TIMESTEPS = 24 * 7
STEP = 24 * 1

serieses=[]
nextday=[]

for i in range(0,len(Xh)-TIMESTEPS,STEP):
    serieses.append(np.array(Xh.iloc[i: i + TIMESTEPS]))
    nextday.append(np.array(Xh.iloc[i + TIMESTEPS:i+TIMESTEPS+STEP]))

# %%
print("total days : %d" % (len(Xh)/24))
print("total sample: %d" % len(nextday))
#Xh[-24:].values == nextday[-1]
# Out:
# total days : 113
# total sample: 106

# %%
X_train=np.array(serieses[:-6]);Y_train=np.array(nextday[:-6])
X_test=np.array(serieses[-6:]);Y_test=np.array(nextday[-6:])

# %%
'''
print(X_train.shape)
print(Y_train.shape)
Y_train=Y_train.reshape(Y_train.shape[0],Y_train.shape[1])
print(Y_train.shape)#
'''
# Out:
# '\nprint(X_train.shape)\nprint(Y_train.shape)\nY_train=Y_train.reshape(Y_train.shape[0],Y_train.shape[1])\nprint(Y_train.shape)#\n'

# %%
'''
model = Sequential()
model.add(LSTM(96, input_shape=(168,1), init="normal"))
model.add(Dense(24,init="normal"))
'''
# Out:
# '\nmodel = Sequential()\nmodel.add(LSTM(96, input_shape=(168,1), init="normal"))\nmodel.add(Dense(24,init="normal"))\n'

# %%
print(X_train.shape)
print(Y_train.shape)
X_train=X_train.reshape(100,24,7)
Y_train=Y_train.reshape(Y_train.shape[0],Y_train.shape[1])
print(X_train.shape)
print(Y_train.shape)
X_test = X_test.reshape(X_test.shape[0],24,7)
Y_test = Y_test.reshape(Y_test.shape[0],24)
# Out:
# (100, 168, 1)
# (100, 24, 1)
# (100, 24, 7)
# (100, 24)

# %%
model = Sequential()
model.add(LSTM(96, input_shape=(24,7), init="normal"))
model.add(Dense(24,init="normal"))
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(96, input_shape=(24, 7), kernel_initializer="normal")`
#
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(24, kernel_initializer="normal")`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(X_train.shape)
print(Y_train.shape)
X_train=X_train.reshape(100,24,7)
X_train = X_train.transpose((0,2,1))
Y_train=Y_train.reshape(Y_train.shape[0],Y_train.shape[1])
print(X_train.shape)
print(Y_train.shape)
X_test = X_test.reshape(X_test.shape[0],24,7)
X_test = X_test.transpose((0,2,1))
Y_test = Y_test.reshape(Y_test.shape[0],24)
# Out:
# (100, 168, 1)
# (100, 24, 1)
# (100, 7, 24)
# (100, 24)

# %%
#X_train.transpose((0,2,1))

# %%
#X_train

# %%
model = Sequential()
model.add(LSTM(96, input_shape=(7,24), init="normal"))
model.add(Dense(24,init="normal"))
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(96, input_shape=(7, 24), kernel_initializer="normal")`
#
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(24, kernel_initializer="normal")`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#model.compile(loss='mae', optimizer='adam')

# %%
model.compile(loss='mean_squared_error', 
              optimizer=keras.optimizers.SGD(lr=0.1))

# %%
model.fit(X_train, Y_train, epochs=14,batch_size=10, shuffle=False,verbose=2,validation_split=0.2)
# Out:
# Train on 80 samples, validate on 20 samples
# Epoch 1/14
#  - 1s - loss: 0.0126 - val_loss: 0.0029
# Epoch 2/14
#  - 0s - loss: 0.0115 - val_loss: 0.0024
# Epoch 3/14
#  - 0s - loss: 0.0106 - val_loss: 0.0019
# Epoch 4/14
#  - 0s - loss: 0.0098 - val_loss: 0.0016
# Epoch 5/14
#  - 0s - loss: 0.0092 - val_loss: 0.0013
# Epoch 6/14
#  - 0s - loss: 0.0086 - val_loss: 0.0011
# Epoch 7/14
#  - 0s - loss: 0.0081 - val_loss: 9.1032e-04
# Epoch 8/14
#  - 0s - loss: 0.0077 - val_loss: 7.7767e-04
# Epoch 9/14
#  - 0s - loss: 0.0073 - val_loss: 6.7834e-04
# Epoch 10/14
#  - 0s - loss: 0.0070 - val_loss: 6.0618e-04
# Epoch 11/14
#  - 0s - loss: 0.0068 - val_loss: 5.5604e-04
# Epoch 12/14
#  - 0s - loss: 0.0065 - val_loss: 5.2364e-04
# Epoch 13/14
#  - 0s - loss: 0.0064 - val_loss: 5.0545e-04
# Epoch 14/14
#  - 0s - loss: 0.0062 - val_loss: 4.9850e-04

# %%
model.save("model_1.h5")

# %%
from keras.models import load_model
model = load_model('model_1.h5')

# %%
pred_test=model.predict(X_test)
pred_train = model.predict(X_train)

# %%
import matplotlib.pyplot as plt

# %%
import pylab
pylab.rcParams['figure.figsize'] = (12.0, 4.0)

# %%
for i in range(pred_test.shape[0]):
    plt.plot(pred_test[i,:])
#    plt.plot(y[3,:])

# %%
for i in range(pred_train.shape[0]):
    plt.plot(pred_train[i,:])
#    plt.plot(y[3,:])

# %%
for i in range(Y_train.shape[0]):
    plt.plot(Y_train[i])
#    plt.plot(y[3,:])

# %%
for i in range(Y_test.shape[0]):
    plt.plot(Y_test[i])

# %%
plt.plot(Y_train[5])
plt.plot(pred_train[5,:])

# %%
result[:50].plot(alpha =0.5,figsize = (12,4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-9bf6d2518839> in <module>()
# ----> 1 result[:50].plot(alpha =0.5,figsize = (12,4))
#
# NameError: name 'result' is not defined

# %%
a=y.reshape(1440)

# %%
result=df.iloc[-1440:]

# %%
result["pred"]=a*(Max-Min).values+Min.values
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
result.loc["pred"]=result.pred*(Max.values-Min.values)+Min.values
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
result[10:60]
# Out:
#                            值       pred
# 序列
# 2017-12-17 02:45:00   1.9446   2.619534
# 2017-12-17 03:00:00   2.1909   2.409545
# 2017-12-17 03:15:00   2.2726   2.402391
# 2017-12-17 03:30:00   2.1879   2.440498
# 2017-12-17 03:45:00   2.3731   2.421886
# 2017-12-17 04:00:00   2.1781   2.503651
# 2017-12-17 04:15:00   2.1306   2.454529
# 2017-12-17 04:30:00   2.2826   2.399416
# 2017-12-17 04:45:00   2.4268   2.442887
# 2017-12-17 05:00:00   2.2806   2.542484
# 2017-12-17 05:15:00   2.2326   2.527765
# 2017-12-17 05:30:00   2.0973   2.491588
# 2017-12-17 05:45:00   2.1810   2.400108
# 2017-12-17 06:00:00   3.0168   2.387536
# 2017-12-17 06:15:00   2.7135   2.801938
# 2017-12-17 06:30:00   2.7809   2.896589
# 2017-12-17 06:45:00   2.0649   2.974382
# 2017-12-17 07:00:00   2.4439   2.648257
# 2017-12-17 07:15:00   3.9250   2.633186
# 2017-12-17 07:30:00   4.9934   3.367869
# 2017-12-17 07:45:00   7.6765   4.338260
# 2017-12-17 08:00:00   7.5353   6.233838
# 2017-12-17 08:15:00   9.9841   7.227449
# 2017-12-17 08:30:00  13.5560   8.936916
# 2017-12-17 08:45:00  23.1229  11.617056
# 2017-12-17 09:00:00  20.0403  17.830182
# 2017-12-17 09:15:00  19.3426  19.719111
# 2017-12-17 09:30:00  17.2316  20.101485
# 2017-12-17 09:45:00  16.2904  18.901037
# 2017-12-17 10:00:00  16.1266  17.414596
# 2017-12-17 10:15:00  14.2495  16.249837
# 2017-12-17 10:30:00  13.5904  14.511334
# 2017-12-17 10:45:00  15.8033  13.108966
# 2017-12-17 11:00:00  18.4640  13.411392
# 2017-12-17 11:15:00  18.0245  14.985554
# 2017-12-17 11:30:00  11.9773  15.736431
# 2017-12-17 11:45:00   8.9019  13.140528
# 2017-12-17 12:00:00   8.0754  10.038462
# 2017-12-17 12:15:00   5.8220   7.854813
# 2017-12-17 12:30:00   6.0910   5.591674
# 2017-12-17 12:45:00   5.5925   4.590052
# 2017-12-17 13:00:00   5.4874   3.985003
# 2017-12-17 13:15:00   6.3765   3.798750
# 2017-12-17 13:30:00   5.9040   4.333661
# 2017-12-17 13:45:00   5.5151   4.576763
# 2017-12-17 14:00:00   6.0288   4.638206
# 2017-12-17 14:15:00  10.6108   5.013154
# 2017-12-17 14:30:00   6.1973   7.595436
# 2017-12-17 14:45:00   5.6464   6.934719
# 2017-12-17 15:00:00   4.4648   6.210394

# %%
(a*(Max-Min).values+Min.values).shape
# Out:
# (1440,)
