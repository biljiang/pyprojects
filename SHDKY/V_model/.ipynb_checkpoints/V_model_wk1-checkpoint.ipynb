# %%
import numpy as np
import pandas as pd
import pathlib as pl
from datetime import datetime
import matplotlib.pyplot as plot
from pandas import DataFrame, Series
import seaborn as sb

# %%
# read from csv files

datapath=pl.Path("../csvdata")

file_list=[]
dfs=[]
for x in datapath.glob("*[0-9].csv"):
    print("Reading "+x.name)
    f=pd.read_csv(x,index_col=0,na_values=" ")
    dfs.append(f)
    file_list.append(x.name)
# Out:
# Reading kVKunYang3.csv
# Reading kVWanKe1.csv
# Reading kVChangLiu3.csv
# Reading kVJiangChuan1.csv
# Reading kVChangLiu2.csv
# Reading kVQinZhou4.csv
# Reading kVChangLiu1.csv
# Reading kVJiangChuan4.csv
# Reading kVJiangChuan5.csv
# Reading kVQinZhou3.csv
# Reading kVKunYang1.csv
# Reading kVJiangChuan3.csv
# Reading kVJiangChuan2.csv
# Reading kVChangLiu4.csv
# Reading kVWanKe2.csv

# %%
cols = ["Avg[V 有效值 AB]",
# "Avg[V 总谐波畸变率 A]",
 "Avg[V 负序不平衡 Total]",
 "Avg[V SPOS All]",
 "Avg[V SNEG All]",
 "Avg[V SZERO All]",
#"Pst A",
 "Avg[I 有效值 A]",
 "Avg[I 总谐波畸变率 A]",
 "Avg[I 负序不平衡 Total]",
 "Avg[I SPOS All]",
 "Avg[I SNEG All]",
 "Avg[I ZERO All]",
# "Avg[P A]",
# "Avg[Q A]",
# "Avg[S A]",
# "Avg[功率因数 A]"
 ]

# %%
tr_data=DataFrame()
i=0
for df in dfs:
    for c in df.columns:
        if c.find("Avg[V 有效值 A]")!=-1:
            print (c)
            tr_data[c]=df[c]
            i+=1
print(i)
# Out:
#  KunYang3 - Avg[V 有效值 A] (V)
#  WanKe1 - Avg[V 有效值 A] (V)
#  Changliu3 - Avg[V 有效值 A] (V)
#  JiangChuan1 - Avg[V 有效值 A] (V)
#  Changliu2 - Avg[V 有效值 A] (V)
#  QinZhou4 - Avg[V 有效值 A] (V)
#  Changliu1 - Avg[V 有效值 A] (V)
#  JiangChuan4 - Avg[V 有效值 A] (V)
#  JiangChuan5 - Avg[V 有效值 A] (V)
#  QinZhou3 - Avg[V 有效值 A] (V)
#  KunYang1 - Avg[V 有效值 A] (V)
#  JiangChuan3 - Avg[V 有效值 A] (V)
#  JiangChuan2 - Avg[V 有效值 A] (V)
#  Changliu4 - Avg[V 有效值 A] (V)
#  WanKe2 - Avg[V 有效值 A] (V)
# 15

# %%
train_data=tr_data.dropna()
#train_data.index=pd.to_datetime(train_data.index)

# %%
len(train_data)
# Out:
# 3299

# %%
corMat=DataFrame(train_data.corr())
plot.pcolor(corMat)
plot.show()

# %%
sb.heatmap(corMat)
plot.show()

# %%
train_data.describe()
# Out:
#         KunYang3 - Avg[V 有效值 A] (V)   WanKe1 - Avg[V 有效值 A] (V)  \
# count                   3299.000000                 3299.000000
# mean                    5976.121993                 5986.850334
# std                       64.430676                   55.894008
# min                     5830.702148                 5817.614746
# 25%                     5925.785889                 5949.191650
# 50%                     5958.308594                 5970.171875
# 75%                     6033.386719                 6034.218506
# max                     6109.875000                 6112.416992
#
#         Changliu3 - Avg[V 有效值 A] (V)   JiangChuan1 - Avg[V 有效值 A] (V)  \
# count                    3299.000000                      3299.000000
# mean                    66347.706727                     66931.515779
# std                       514.966488                       481.909711
# min                     65415.679688                     65950.992188
# 25%                     65960.445312                     66520.015625
# 50%                     66210.750000                     66853.265625
# 75%                     66804.027344                     67337.765625
# max                     67461.664062                     67982.156250
#
#         Changliu2 - Avg[V 有效值 A] (V)   QinZhou4 - Avg[V 有效值 A] (V)  \
# count                    3299.000000                   3299.000000
# mean                    66343.090503                   6027.883281
# std                       459.519353                     40.939587
# min                     65407.289062                   5889.572754
# 25%                     66026.281250                   5998.149414
# 50%                     66253.203125                   6030.515625
# 75%                     66678.726562                   6062.003662
# max                     67357.781250                   6116.090332
#
#         Changliu1 - Avg[V 有效值 A] (V)   JiangChuan4 - Avg[V 有效值 A] (V)  \
# count                    3299.000000                      3299.000000
# mean                    66329.945985                     21184.473580
# std                       459.518445                       171.527872
# min                     65392.582031                     20772.759766
# 25%                     66012.910156                     21042.520508
# 50%                     66239.914062                     21161.919922
# 75%                     66665.218750                     21330.924805
# max                     67345.562500                     21552.068359
#
#         JiangChuan5 - Avg[V 有效值 A] (V)   QinZhou3 - Avg[V 有效值 A] (V)  \
# count                      3299.000000                   3299.000000
# mean                      21054.456651                   6063.167116
# std                         180.797627                     33.621357
# min                       20674.398438                   5952.262207
# 25%                       20905.112305                   6043.062012
# 50%                       21007.013672                   6062.074707
# 75%                       21232.261719                   6082.279053
# max                       21419.802734                   6168.177734
#
#         KunYang1 - Avg[V 有效值 A] (V)   JiangChuan3 - Avg[V 有效值 A] (V)  \
# count                   3299.000000                      3299.000000
# mean                   20868.165318                     64557.467277
# std                      221.995064                       699.083497
# min                    20356.412109                     63357.675781
# 25%                    20696.790039                     63989.738281
# 50%                    20807.066406                     64308.441406
# 75%                    21061.987305                     65302.509766
# max                    21322.738281                     65889.218750
#
#         JiangChuan2 - Avg[V 有效值 A] (V)   Changliu4 - Avg[V 有效值 A] (V)  \
# count                      3299.000000                    3299.000000
# mean                      66220.021129                   66359.707375
# std                         380.350509                     515.197702
# min                       65389.726562                   65427.441406
# 25%                       65931.167969                   65972.527344
# 50%                       66159.289062                   66222.867188
# 75%                       66530.695312                   66816.386719
# max                       67125.125000                   67473.921875
#
#         WanKe2 - Avg[V 有效值 A] (V)
# count                 3299.000000
# mean                  6070.998084
# std                     37.981018
# min                   5999.132812
# 25%                   6041.693604
# 50%                   6062.486328
# 75%                   6100.305176
# max                   6157.926758

# %%
from sklearn.model_selection import train_test_split
train,test= train_test_split(train_data,test_size=0.2,random_state=0)

# %%
MAX= train.max()
MIN = train.min()

# %%
train_s=(train-MIN)/(MAX-MIN)
test_s=(test-MIN)/(MAX-MIN)

# %%
#  generate X_train,Y_train,X_test,Y_test for all target features
X_train=train_s.copy();Y_train=DataFrame()

for c in train_s.columns:
    if c.find("WanKe1") !=-1 :
        Y_train[c]=train_s[c]
        X_train=X_train.drop(c,axis=1)

        
X_test=test_s.copy();Y_test=DataFrame()

for c in test_s.columns:
    if c.find("WanKe1") !=-1 :
        Y_test[c]=test_s[c]
        X_test=X_test.drop(c,axis=1)

# %%
###### network from keras for SHDKY data simulation ###########
from keras.models import Sequential
from keras.layers import Dense, Activation,Input
import keras


model = Sequential()

model.add(Dense(14, input_dim=14,kernel_initializer="normal"))
model.add(Activation('relu'))
model.add(Dense(7, activation='relu',kernel_initializer="normal"))
model.add(Dense(1, activation='linear',kernel_initializer="normal"))
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model.compile(loss='mean_squared_error', 
              optimizer=keras.optimizers.SGD(lr=0.01))

# %%
model.fit(X_train, Y_train, epochs=30,batch_size=30,
          shuffle=True,verbose=2,validation_split=0.2)
# Out:
# Train on 2111 samples, validate on 528 samples
# Epoch 1/30
#  - 0s - loss: 0.0032 - val_loss: 0.0041
# Epoch 2/30
#  - 0s - loss: 0.0031 - val_loss: 0.0042
# Epoch 3/30
#  - 0s - loss: 0.0032 - val_loss: 0.0040
# Epoch 4/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 5/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 6/30
#  - 0s - loss: 0.0032 - val_loss: 0.0040
# Epoch 7/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 8/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 9/30
#  - 0s - loss: 0.0032 - val_loss: 0.0042
# Epoch 10/30
#  - 0s - loss: 0.0031 - val_loss: 0.0046
# Epoch 11/30
#  - 0s - loss: 0.0032 - val_loss: 0.0041
# Epoch 12/30
#  - 0s - loss: 0.0032 - val_loss: 0.0054
# Epoch 13/30
#  - 0s - loss: 0.0032 - val_loss: 0.0046
# Epoch 14/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 15/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 16/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 17/30
#  - 0s - loss: 0.0031 - val_loss: 0.0042
# Epoch 18/30
#  - 0s - loss: 0.0032 - val_loss: 0.0043
# Epoch 19/30
#  - 0s - loss: 0.0031 - val_loss: 0.0046
# Epoch 20/30
#  - 0s - loss: 0.0032 - val_loss: 0.0042
# Epoch 21/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 22/30
#  - 0s - loss: 0.0032 - val_loss: 0.0041
# Epoch 23/30
#  - 0s - loss: 0.0032 - val_loss: 0.0040
# Epoch 24/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 25/30
#  - 0s - loss: 0.0031 - val_loss: 0.0042
# Epoch 26/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 27/30
#  - 0s - loss: 0.0031 - val_loss: 0.0043
# Epoch 28/30
#  - 0s - loss: 0.0031 - val_loss: 0.0040
# Epoch 29/30
#  - 0s - loss: 0.0032 - val_loss: 0.0040
# Epoch 30/30
#  - 0s - loss: 0.0031 - val_loss: 0.0042

# %%
from keras.models import load_model
model = load_model("model_h5/M_V.h5")
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
((model.predict(X_test)-Y_test)).describe()
# Out:
#         WanKe1 - Avg[V 有效值 A] (V)
# count                  660.000000
# mean                    -0.003411
# std                      0.051287
# min                     -0.292831
# 25%                     -0.025946
# 50%                     -0.001624
# 75%                      0.020343
# max                      0.347420

# %%
Y_test.describe()
# Out:
#         WanKe1 - Avg[V 有效值 A] (V)
# count                  660.000000
# mean                     0.573928
# std                      0.191149
# min                      0.025515
# 25%                      0.443539
# 50%                      0.515683
# 75%                      0.737798
# max                      0.985771

# %%
X_test.columns
# Out:
# Index([' KunYang3 - Avg[V 有效值 A] (V)', ' Changliu3 - Avg[V 有效值 A] (V)',
#        ' JiangChuan1 - Avg[V 有效值 A] (V)', ' Changliu2 - Avg[V 有效值 A] (V)',
#        ' QinZhou4 - Avg[V 有效值 A] (V)', ' Changliu1 - Avg[V 有效值 A] (V)',
#        ' JiangChuan4 - Avg[V 有效值 A] (V)', ' JiangChuan5 - Avg[V 有效值 A] (V)',
#        ' QinZhou3 - Avg[V 有效值 A] (V)', ' KunYang1 - Avg[V 有效值 A] (V)',
#        ' JiangChuan3 - Avg[V 有效值 A] (V)', ' JiangChuan2 - Avg[V 有效值 A] (V)',
#        ' Changliu4 - Avg[V 有效值 A] (V)', ' WanKe2 - Avg[V 有效值 A] (V)'],
#       dtype='object')

# %%
((model.predict(X_test)-Y_test)/Y_test)[:10]
# Out:
#                       WanKe1 - Avg[V 有效值 A] (V)
# 时间
# 2018-02-02 05:24:00                    0.044158
# 2018-02-01 01:42:00                    0.002289
# 2018-02-02 20:36:00                   -0.050768
# 2018-02-07 13:15:00                   -0.027716
# 2018-02-03 09:27:00                   -0.172787
# 2018-02-05 09:48:00                   -0.011153
# 2018-02-06 10:06:00                    0.176217
# 2018-02-02 05:06:00                    0.008387
# 2018-02-02 10:24:00                    0.084590
# 2018-02-04 16:12:00                    0.132668

# %%
c=Y_test.columns
R= pd.DataFrame(model.predict(X_test),columns=['V_pred'])
R.index = Y_test.index
R= R.join(Y_test)
#R=  R*((MAX[c]-MIN[c])+MIN[c]).values[0]
R=  R*(MAX[c]-MIN[c]).values[0]+MIN[c].values[0]

# %%
R_show=R.iloc[200:300,:]

import pylab
pylab.rcParams['figure.figsize'] = (12.0, 4.0)

R_show.plot(alpha =0.5,figsize = (12,4))

# %%
R["diff"]=(R["V_pred"]-R[c[0]])
R["diff_ptg"]=(R["V_pred"]-R[c[0]])/R[c[0]]

# %%
R.describe()
# Out:
#             V_pred   WanKe1 - Avg[V 有效值 A] (V)        diff    diff_ptg
# count   660.000000                  660.000000  660.000000  660.000000
# mean   5985.803711                 5986.810097   -1.005692   -0.000161
# std      53.640400                   56.351261   15.119396    0.002532
# min    5880.494629                 5825.136719  -86.327148   -0.014133
# 25%    5948.320312                 5948.371094   -7.648926   -0.001276
# 50%    5969.029297                 5969.639160   -0.479004   -0.000080
# 75%    6027.700439                 6035.119141    5.997314    0.000999
# max    6097.600586                 6108.222168  102.419922    0.017582

# %%
(R.diff_ptg.quantile(0.005),R.diff_ptg.quantile(0.995))
# Out:
# (-0.011455302120607318, 0.008034679354775672)

# %%
R.corr()
# Out:
#                               V_pred   WanKe1 - Avg[V 有效值 A] (V)      diff  \
# V_pred                      1.000000                    0.963402 -0.042895
#  WanKe1 - Avg[V 有效值 A] (V)  0.963402                    1.000000 -0.309138
# diff                       -0.042895                   -0.309138  1.000000
# diff_ptg                   -0.043765                   -0.309936  0.999889
#
#                             diff_ptg
# V_pred                     -0.043765
#  WanKe1 - Avg[V 有效值 A] (V) -0.309936
# diff                        0.999889
# diff_ptg                    1.000000

# %%
train_data.corr()[c[0]].sort_values()
# Out:
#  QinZhou4 - Avg[V 有效值 A] (V)      -0.247935
#  QinZhou3 - Avg[V 有效值 A] (V)      -0.040098
#  JiangChuan2 - Avg[V 有效值 A] (V)    0.643617
#  KunYang1 - Avg[V 有效值 A] (V)       0.644071
#  KunYang3 - Avg[V 有效值 A] (V)       0.651253
#  JiangChuan1 - Avg[V 有效值 A] (V)    0.655107
#  JiangChuan4 - Avg[V 有效值 A] (V)    0.660598
#  Changliu2 - Avg[V 有效值 A] (V)      0.714679
#  Changliu1 - Avg[V 有效值 A] (V)      0.714874
#  JiangChuan3 - Avg[V 有效值 A] (V)    0.724374
#  JiangChuan5 - Avg[V 有效值 A] (V)    0.742471
#  Changliu3 - Avg[V 有效值 A] (V)      0.745863
#  Changliu4 - Avg[V 有效值 A] (V)      0.745891
#  WanKe2 - Avg[V 有效值 A] (V)         0.778024
#  WanKe1 - Avg[V 有效值 A] (V)         1.000000
# Name:  WanKe1 - Avg[V 有效值 A] (V), dtype: float64

# %%
model.save("model_h5/M_V.h5")

# %%
test[c][:6]
# Out:
#                       WanKe1 - Avg[V 有效值 A] (V)
# 时间
# 2018-02-02 05:24:00                 6050.011230
# 2018-02-01 01:42:00                 6055.016602
# 2018-02-02 20:36:00                 5969.651855
# 2018-02-07 13:15:00                 5964.648926
# 2018-02-03 09:27:00                 5977.743164
# 2018-02-05 09:48:00                 5928.258301

# %%
R[c][:6]
# Out:
#                       WanKe1 - Avg[V 有效值 A] (V)
# 时间
# 2018-02-02 05:24:00                 6050.011230
# 2018-02-01 01:42:00                 6055.016602
# 2018-02-02 20:36:00                 5969.651855
# 2018-02-07 13:15:00                 5964.648926
# 2018-02-03 09:27:00                 5977.743164
# 2018-02-05 09:48:00                 5928.258301

# %%
R.diff_ptg.hist(bins=100)

# %%
len(train_data[c]["2018-02-05"])
# Out:
# 420

# %%
train_data[c]['2018-02-05 08:45':'2018-02-05 09:15'].plot()
