# %%
import numpy as np
import pandas as pd
import pathlib as pl
from datetime import datetime
import matplotlib.pyplot as plot
from pandas import DataFrame, Series
import seaborn as sb

# %%
# read from csv files

datapath=pl.Path("../csvdata")

file_list=[]
dfs=[]
for x in datapath.glob("*[0-9].csv"):
    print("Reading "+x.name)
    f=pd.read_csv(x,index_col=0,na_values=" ")
    dfs.append(f)
    file_list.append(x.name)
# Out:
# Reading kVKunYang3.csv
# Reading kVWanKe1.csv
# Reading kVChangLiu3.csv
# Reading kVJiangChuan1.csv
# Reading kVChangLiu2.csv
# Reading kVQinZhou4.csv
# Reading kVChangLiu1.csv
# Reading kVJiangChuan4.csv
# Reading kVJiangChuan5.csv
# Reading kVQinZhou3.csv
# Reading kVKunYang1.csv
# Reading kVJiangChuan3.csv
# Reading kVJiangChuan2.csv
# Reading kVChangLiu4.csv
# Reading kVWanKe2.csv

# %%
cols = ["Avg[V 有效值 AB]",
# "Avg[V 总谐波畸变率 A]",
 "Avg[V 负序不平衡 Total]",
 "Avg[V SPOS All]",
 "Avg[V SNEG All]",
 "Avg[V SZERO All]",
#"Pst A",
 "Avg[I 有效值 A]",
 "Avg[I 总谐波畸变率 A]",
 "Avg[I 负序不平衡 Total]",
 "Avg[I SPOS All]",
 "Avg[I SNEG All]",
 "Avg[I ZERO All]",
# "Avg[P A]",
# "Avg[Q A]",
# "Avg[S A]",
# "Avg[功率因数 A]"
 ]

# %%
tr_data=DataFrame()
i=0
for df in dfs:
    for c in df.columns:
        if c.find("Avg[V 负序不平衡 Total]")!=-1:
            print (c)
            tr_data[c]=df[c]
            i+=1
print(i)
# Out:
#  KunYang3 - Avg[V 负序不平衡 Total] (%)
#  WanKe1 - Avg[V 负序不平衡 Total] (%)
#  Changliu3 - Avg[V 负序不平衡 Total] (%)
#  JiangChuan1 - Avg[V 负序不平衡 Total] (%)
#  Changliu2 - Avg[V 负序不平衡 Total] (%)
#  QinZhou4 - Avg[V 负序不平衡 Total] (%)
#  Changliu1 - Avg[V 负序不平衡 Total] (%)
#  JiangChuan4 - Avg[V 负序不平衡 Total] (%)
#  JiangChuan5 - Avg[V 负序不平衡 Total] (%)
#  QinZhou3 - Avg[V 负序不平衡 Total] (%)
#  KunYang1 - Avg[V 负序不平衡 Total] (%)
#  JiangChuan3 - Avg[V 负序不平衡 Total] (%)
#  JiangChuan2 - Avg[V 负序不平衡 Total] (%)
#  Changliu4 - Avg[V 负序不平衡 Total] (%)
#  WanKe2 - Avg[V 负序不平衡 Total] (%)
# 15

# %%
train_data=tr_data.dropna()
train_data.index=pd.to_datetime(train_data.index)

# %%
len(train_data)
# Out:
# 3299

# %%
train_data=train_data.dropna(axis=1)

# %%
corMat=DataFrame(train_data.corr())
plot.pcolor(corMat)
plot.show()

# %%
sb.heatmap(corMat)
plot.show()

# %%
train_data.describe()
# Out:
#         KunYang3 - Avg[V 负序不平衡 Total] (%)   WanKe1 - Avg[V 负序不平衡 Total] (%)  \
# count                         3299.000000                       3299.000000
# mean                             0.327517                          0.191020
# std                              0.039670                          0.073670
# min                              0.240446                          0.037254
# 25%                              0.298295                          0.130374
# 50%                              0.327135                          0.186988
# 75%                              0.352547                          0.245463
# max                              0.526052                          0.471749
#
#         Changliu3 - Avg[V 负序不平衡 Total] (%)  \
# count                          3299.000000
# mean                              0.095428
# std                               0.044045
# min                               0.000000
# 25%                               0.060178
# 50%                               0.084825
# 75%                               0.132259
# max                               0.211169
#
#         JiangChuan1 - Avg[V 负序不平衡 Total] (%)  \
# count                            3299.000000
# mean                                0.111909
# std                                 0.045501
# min                                 0.000000
# 25%                                 0.076814
# 50%                                 0.116619
# 75%                                 0.133581
# max                                 0.297531
#
#         Changliu2 - Avg[V 负序不平衡 Total] (%)  \
# count                          3299.000000
# mean                              0.081968
# std                               0.041208
# min                               0.000000
# 25%                               0.059600
# 50%                               0.083100
# 75%                               0.119496
# max                               0.179408
#
#         QinZhou4 - Avg[V 负序不平衡 Total] (%)  \
# count                         3299.000000
# mean                             0.125303
# std                              0.042323
# min                              0.000000
# 25%                              0.094099
# 50%                              0.124629
# 75%                              0.152113
# max                              0.307059
#
#         Changliu1 - Avg[V 负序不平衡 Total] (%)  \
# count                          3299.000000
# mean                              0.075827
# std                               0.037737
# min                               0.000000
# 25%                               0.057344
# 50%                               0.079298
# 75%                               0.107706
# max                               0.170129
#
#         JiangChuan4 - Avg[V 负序不平衡 Total] (%)  \
# count                            3299.000000
# mean                                0.131371
# std                                 0.065309
# min                                 0.000000
# 25%                                 0.081530
# 50%                                 0.129140
# 75%                                 0.175011
# max                                 0.427214
#
#         JiangChuan5 - Avg[V 负序不平衡 Total] (%)  \
# count                            3299.000000
# mean                                0.114935
# std                                 0.054257
# min                                 0.000000
# 25%                                 0.071730
# 50%                                 0.118101
# 75%                                 0.143536
# max                                 0.316012
#
#         QinZhou3 - Avg[V 负序不平衡 Total] (%)   KunYang1 - Avg[V 负序不平衡 Total] (%)  \
# count                         3299.000000                         3299.000000
# mean                             0.154856                            0.367229
# std                              0.045104                            0.093906
# min                              0.004340                            0.215298
# 25%                              0.124470                            0.302231
# 50%                              0.152641                            0.341570
# 75%                              0.184459                            0.424629
# max                              0.341848                            1.106084
#
#         JiangChuan3 - Avg[V 负序不平衡 Total] (%)  \
# count                            3299.000000
# mean                                0.132918
# std                                 0.052112
# min                                 0.000259
# 25%                                 0.093268
# 50%                                 0.130975
# 75%                                 0.171459
# max                                 0.318645
#
#         JiangChuan2 - Avg[V 负序不平衡 Total] (%)  \
# count                            3299.000000
# mean                                0.151968
# std                                 0.045781
# min                                 0.053293
# 25%                                 0.118707
# 50%                                 0.153264
# 75%                                 0.185609
# max                                 0.294376
#
#         Changliu4 - Avg[V 负序不平衡 Total] (%)   WanKe2 - Avg[V 负序不平衡 Total] (%)
# count                          3299.000000                       3299.000000
# mean                              0.087293                          0.239513
# std                               0.045654                          0.061867
# min                               0.000000                          0.068352
# 25%                               0.058624                          0.194439
# 50%                               0.084147                          0.234231
# 75%                               0.126382                          0.278918
# max                               0.183200                          0.515196

# %%
from sklearn.model_selection import train_test_split
train,test= train_test_split(train_data,test_size=0.2,random_state=0)

# %%
MAX= train.max()
MIN = train.min()

# %%
train_s=(train-MIN)/(MAX-MIN)
test_s=(test-MIN)/(MAX-MIN)

# %%
train_s=train_s.fillna(0)
test_s=test_s.fillna(0)

# %%
#  generate X_train,Y_train,X_test,Y_test for all target features
X_train=train_s.copy();Y_train=DataFrame()

for c in train_s.columns:
    if c.find("WanKe1") !=-1 :
        Y_train[c]=train_s[c]
        X_train=X_train.drop(c,axis=1)

        
X_test=test_s.copy();Y_test=DataFrame()

for c in test_s.columns:
    if c.find("WanKe1") !=-1 :
        Y_test[c]=test_s[c]
        X_test=X_test.drop(c,axis=1)

# %%
###### network from keras for SHDKY data simulation ###########
'''
from keras.models import Sequential
from keras.layers import Dense, Activation,Input,Dropout
import keras


model = Sequential()

model.add(Dense(28, input_dim=14,kernel_initializer="normal"))
model.add(Activation('relu'))
#model.add(Dense(14, activation='relu',kernel_initializer="normal"))
#model.add(Dropout(0.5))
model.add(Dense(7, activation='relu',kernel_initializer="normal"))
#model.add(Dropout(0.5))
model.add(Dense(1, activation='linear',kernel_initializer="normal"))
'''
# Out:
# '\nfrom keras.models import Sequential\nfrom keras.layers import Dense, Activation,Input,Dropout\nimport keras\n\n\nmodel = Sequential()\n\nmodel.add(Dense(28, input_dim=14,kernel_initializer="normal"))\nmodel.add(Activation(\'relu\'))\n#model.add(Dense(14, activation=\'relu\',kernel_initializer="normal"))\n#model.add(Dropout(0.5))\nmodel.add(Dense(7, activation=\'relu\',kernel_initializer="normal"))\n#model.add(Dropout(0.5))\nmodel.add(Dense(1, activation=\'linear\',kernel_initializer="normal"))\n'

# %%
###### network from keras for SHDKY data simulation ###########
from keras.models import Sequential
from keras.layers import Dense, Activation,Input,Dropout
import keras
from keras import regularizers

model = Sequential()

#model.add(Dense(14, input_dim=14,kernel_initializer="normal",kernel_regularizer=regularizers.l2(0.02)))
#model.add(Activation('tanh'))
#model.add(Dense(7,activation='tanh',kernel_initializer="normal",kernel_regularizer=regularizers.l2(0.02)))
#model.add(Dense(1, activation='linear',kernel_initializer="normal",kernel_regularizer=regularizers.l2(0.01)))

model.add(Dense(2048, input_dim=14,kernel_initializer="VarianceScaling"))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(128,activation='relu',kernel_initializer="VarianceScaling"))
model.add(Dropout(0.5))
#model.add(Dense(32,activation='relu',kernel_initializer="VarianceScaling"))
model.add(Dense(1, activation='linear',kernel_initializer="normal",kernel_regularizer=regularizers.l2(0.8)))
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#model.compile(loss='mse', 
#              optimizer=keras.optimizers.SGD(lr=0.02))

# %%
model.compile(loss='mse', 
              optimizer="adam",
              metrics=['mse'])

# %%
model.fit(X_train, Y_train, epochs=20,batch_size=30,
          shuffle=True,verbose=2,validation_split=0.2)
# Out:
# Train on 2111 samples, validate on 528 samples
# Epoch 1/20
#  - 0s - loss: 0.0041 - mean_squared_error: 0.0036 - val_loss: 0.0057 - val_mean_squared_error: 0.0052
# Epoch 2/20
#  - 0s - loss: 0.0041 - mean_squared_error: 0.0035 - val_loss: 0.0055 - val_mean_squared_error: 0.0050
# Epoch 3/20
#  - 0s - loss: 0.0048 - mean_squared_error: 0.0042 - val_loss: 0.0057 - val_mean_squared_error: 0.0051
# Epoch 4/20
#  - 0s - loss: 0.0045 - mean_squared_error: 0.0039 - val_loss: 0.0065 - val_mean_squared_error: 0.0060
# Epoch 5/20
#  - 0s - loss: 0.0043 - mean_squared_error: 0.0037 - val_loss: 0.0056 - val_mean_squared_error: 0.0050
# Epoch 6/20
#  - 0s - loss: 0.0039 - mean_squared_error: 0.0034 - val_loss: 0.0060 - val_mean_squared_error: 0.0053
# Epoch 7/20
#  - 0s - loss: 0.0043 - mean_squared_error: 0.0037 - val_loss: 0.0061 - val_mean_squared_error: 0.0055
# Epoch 8/20
#  - 0s - loss: 0.0042 - mean_squared_error: 0.0037 - val_loss: 0.0060 - val_mean_squared_error: 0.0054
# Epoch 9/20
#  - 0s - loss: 0.0050 - mean_squared_error: 0.0044 - val_loss: 0.0060 - val_mean_squared_error: 0.0053
# Epoch 10/20
#  - 0s - loss: 0.0042 - mean_squared_error: 0.0037 - val_loss: 0.0060 - val_mean_squared_error: 0.0055
# Epoch 11/20
#  - 0s - loss: 0.0045 - mean_squared_error: 0.0040 - val_loss: 0.0059 - val_mean_squared_error: 0.0053
# Epoch 12/20
#  - 0s - loss: 0.0043 - mean_squared_error: 0.0038 - val_loss: 0.0058 - val_mean_squared_error: 0.0052
# Epoch 13/20
#  - 0s - loss: 0.0042 - mean_squared_error: 0.0037 - val_loss: 0.0058 - val_mean_squared_error: 0.0053
# Epoch 14/20
#  - 0s - loss: 0.0042 - mean_squared_error: 0.0037 - val_loss: 0.0058 - val_mean_squared_error: 0.0051
# Epoch 15/20
#  - 0s - loss: 0.0045 - mean_squared_error: 0.0040 - val_loss: 0.0069 - val_mean_squared_error: 0.0064
# Epoch 16/20
#  - 0s - loss: 0.0043 - mean_squared_error: 0.0037 - val_loss: 0.0061 - val_mean_squared_error: 0.0055
# Epoch 17/20
#  - 0s - loss: 0.0039 - mean_squared_error: 0.0034 - val_loss: 0.0055 - val_mean_squared_error: 0.0049
# Epoch 18/20
#  - 0s - loss: 0.0040 - mean_squared_error: 0.0035 - val_loss: 0.0054 - val_mean_squared_error: 0.0048
# Epoch 19/20
#  - 0s - loss: 0.0041 - mean_squared_error: 0.0036 - val_loss: 0.0056 - val_mean_squared_error: 0.0050
# Epoch 20/20
#  - 0s - loss: 0.0041 - mean_squared_error: 0.0035 - val_loss: 0.0057 - val_mean_squared_error: 0.0052

# %%
history= model.fit(X_train, Y_train, epochs=500,batch_size=50,
                   shuffle=True,verbose=0,validation_split=0.2)

# %%
#((model.predict(X_test)-Y_test)/Y_test)

# %%
import matplotlib.pyplot as plt

import pylab
pylab.rcParams['figure.figsize'] = (12.0, 4.0)

plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
((model.predict(X_test)-Y_test)).describe()
# Out:
#         WanKe1 - Avg[V 负序不平衡 Total] (%)
# count                        660.000000
# mean                           0.017298
# std                            0.079406
# min                           -0.255615
# 25%                           -0.028810
# 50%                            0.020873
# 75%                            0.065511
# max                            0.261441

# %%
c=Y_test.columns
R= pd.DataFrame(model.predict(X_test),columns=['V_pred'])
R.index = Y_test.index
R= R.join(Y_test)
#R=  R*((MAX[c]-MIN[c])+MIN[c]).values[0]
R=  R*(MAX[c]-MIN[c]).values[0]+MIN[c].values[0]

# %%
R_show=R.iloc[200:300,:]

import pylab
pylab.rcParams['figure.figsize'] = (12.0, 4.0)

R_show.plot(alpha =0.5,figsize = (12,4))

# %%
R["diff"]=(R["V_pred"]-R[c[0]])
R["diff_ptg"]=(R["V_pred"]-R[c[0]])/R[c[0]]

# %%
R.describe()
# Out:
#            V_pred   WanKe1 - Avg[V 负序不平衡 Total] (%)        diff    diff_ptg
# count  660.000000                        660.000000  660.000000  660.000000
# mean     0.200154                          0.192638    0.007516    0.097599
# std      0.060528                          0.074610    0.034501    0.242397
# min      0.068278                          0.043759   -0.111064   -0.452539
# 25%      0.152568                          0.129893   -0.012518   -0.053413
# 50%      0.193440                          0.185849    0.009069    0.052986
# 75%      0.243521                          0.248004    0.028464    0.195014
# max      0.436850                          0.418992    0.113595    1.620725

# %%
(R.diff_ptg.quantile(0.05),R.diff_ptg.quantile(0.95))
# Out:
# (-0.1974879301666425, 0.5725451427185031)

# %%
R.sort_values("diff_ptg")[-6:]
# Out:
#                        V_pred   WanKe1 - Avg[V 负序不平衡 Total] (%)      diff  \
# 时间
# 2018-02-01 08:30:00  0.174527                          0.085647  0.088880
# 2018-02-04 18:21:00  0.194165                          0.090099  0.104066
# 2018-02-05 08:36:00  0.179971                          0.082930  0.097041
# 2018-02-01 23:39:00  0.153159                          0.069725  0.083435
# 2018-02-04 23:54:00  0.119534                          0.051312  0.068222
# 2018-02-06 23:54:00  0.134042                          0.051147  0.082895
#
#                      diff_ptg
# 时间
# 2018-02-01 08:30:00  1.037752
# 2018-02-04 18:21:00  1.155018
# 2018-02-05 08:36:00  1.170151
# 2018-02-01 23:39:00  1.196634
# 2018-02-04 23:54:00  1.329559
# 2018-02-06 23:54:00  1.620725

# %%
R.corr()
# Out:
#                                     V_pred   WanKe1 - Avg[V 负序不平衡 Total] (%)  \
# V_pred                            1.000000                          0.882623
#  WanKe1 - Avg[V 负序不平衡 Total] (%)  0.882623                          1.000000
# diff                              0.144744                         -0.337378
# diff_ptg                          0.056224                         -0.378043
#
#                                       diff  diff_ptg
# V_pred                            0.144744  0.056224
#  WanKe1 - Avg[V 负序不平衡 Total] (%) -0.337378 -0.378043
# diff                              1.000000  0.908328
# diff_ptg                          0.908328  1.000000

# %%
train_data.corr()[c[0]].sort_values()
# Out:
#  KunYang1 - Avg[V 负序不平衡 Total] (%)       0.180370
#  Changliu3 - Avg[V 负序不平衡 Total] (%)      0.216038
#  QinZhou3 - Avg[V 负序不平衡 Total] (%)       0.221983
#  Changliu4 - Avg[V 负序不平衡 Total] (%)      0.227473
#  Changliu2 - Avg[V 负序不平衡 Total] (%)      0.279088
#  JiangChuan4 - Avg[V 负序不平衡 Total] (%)    0.300757
#  JiangChuan2 - Avg[V 负序不平衡 Total] (%)    0.344618
#  Changliu1 - Avg[V 负序不平衡 Total] (%)      0.344836
#  QinZhou4 - Avg[V 负序不平衡 Total] (%)       0.393600
#  JiangChuan5 - Avg[V 负序不平衡 Total] (%)    0.400948
#  JiangChuan1 - Avg[V 负序不平衡 Total] (%)    0.409232
#  JiangChuan3 - Avg[V 负序不平衡 Total] (%)    0.453602
#  KunYang3 - Avg[V 负序不平衡 Total] (%)       0.596734
#  WanKe2 - Avg[V 负序不平衡 Total] (%)         0.778521
#  WanKe1 - Avg[V 负序不平衡 Total] (%)         1.000000
# Name:  WanKe1 - Avg[V 负序不平衡 Total] (%), dtype: float64

# %%
model.save("model_h5/M_V负序.h5")

# %%
test[c][:6]
# Out:
#                       WanKe1 - Avg[V 负序不平衡 Total] (%)
# 时间
# 2018-02-02 05:24:00                          0.228233
# 2018-02-01 01:42:00                          0.116452
# 2018-02-02 20:36:00                          0.306920
# 2018-02-07 13:15:00                          0.223010
# 2018-02-03 09:27:00                          0.196125
# 2018-02-05 09:48:00                          0.271353

# %%
R[c][:6]
# Out:
#                       WanKe1 - Avg[V 负序不平衡 Total] (%)
# 时间
# 2018-02-02 05:24:00                          0.228233
# 2018-02-01 01:42:00                          0.116452
# 2018-02-02 20:36:00                          0.306920
# 2018-02-07 13:15:00                          0.223010
# 2018-02-03 09:27:00                          0.196125
# 2018-02-05 09:48:00                          0.271353

# %%
T = test[[" WanKe1 - Avg[V 负序不平衡 Total] (%)"," WanKe2 - Avg[V 负序不平衡 Total] (%)"]]

# %%
T["diff"]=T[" WanKe2 - Avg[V 负序不平衡 Total] (%)"]-T[" WanKe1 - Avg[V 负序不平衡 Total] (%)"]
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
T["diff_ptg"]=T["diff"]/T[" WanKe1 - Avg[V 负序不平衡 Total] (%)"]
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
T.describe()
# Out:
#         WanKe1 - Avg[V 负序不平衡 Total] (%)   WanKe2 - Avg[V 负序不平衡 Total] (%)  \
# count                        660.000000                        660.000000
# mean                           0.192638                          0.240156
# std                            0.074610                          0.061492
# min                            0.043759                          0.088425
# 25%                            0.129893                          0.196031
# 50%                            0.185849                          0.233483
# 75%                            0.248004                          0.277249
# max                            0.418992                          0.466509
#
#              diff    diff_ptg
# count  660.000000  660.000000
# mean     0.047518    0.366025
# std      0.049882    0.434893
# min     -0.106890   -0.311138
# 25%      0.011778    0.052382
# 50%      0.052176    0.272660
# 75%      0.081946    0.576698
# max      0.183388    2.548187

# %%
R.diff_ptg.hist(bins=100)

# %%
T.diff_ptg.hist(bins=100)

# %%
train_data.index=pd.to_datetime(train_data.index)

# %%
train_data[c]["2018-02-07"].plot()

# %%
pd.to_datetime(train.index[:480])
# Out:
# DatetimeIndex(['2018-02-07 07:39:00', '2018-02-05 23:18:00',
#                '2018-02-07 20:33:00', '2018-02-01 07:30:00',
#                '2018-02-04 07:42:00', '2018-02-05 11:27:00',
#                '2018-02-03 03:57:00', '2018-02-01 16:39:00',
#                '2018-02-06 14:12:00', '2018-02-06 12:39:00',
#                ...
#                '2018-02-04 09:42:00', '2018-02-05 20:12:00',
#                '2018-02-01 07:18:00', '2018-02-01 00:27:00',
#                '2018-02-05 03:45:00', '2018-02-04 05:15:00',
#                '2018-02-06 23:15:00', '2018-02-01 08:09:00',
#                '2018-02-06 04:45:00', '2018-02-04 21:18:00'],
#               dtype='datetime64[ns]', name='时间', length=480, freq=None)
