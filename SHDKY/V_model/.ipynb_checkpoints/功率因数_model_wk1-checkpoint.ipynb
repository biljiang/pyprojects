# %%
import numpy as np
import pandas as pd
import pathlib as pl
from datetime import datetime
import matplotlib.pyplot as plot
from pandas import DataFrame, Series

# %%
# read from csv files

datapath=pl.Path("../csvdata")

file_list=[]
dfs=[]
for x in datapath.glob("*.csv"):
    print("Reading "+x.name)
    f=pd.read_csv(x,index_col=0,na_values=" ")
    dfs.append(f)
    file_list.append(x.name)
# Out:
# Reading kVKunYang3.csv
# Reading kVWanKe1.csv
# Reading kVChangLiu3.csv
# Reading kVJiangChuan1.csv
# Reading kVChangLiu2.csv
# Reading kVQinZhou4.csv
# Reading kVChangLiu1.csv
# Reading kVJiangChuan4.csv
# Reading kVJiangChuan5.csv
# Reading kVQinZhou3.csv
# Reading kVKunYang1.csv
# Reading kVJiangChuan3.csv
# Reading kVJiangChuan2.csv
# Reading kVChangLiu4.csv
# Reading kVWanKe2.csv

# %%
cols = ["Avg[V 有效值 AB]",
# "Avg[V 总谐波畸变率 A]",
 "Avg[V 负序不平衡 Total]",
 "Avg[V SPOS All]",
 "Avg[V SNEG All]",
 "Avg[V SZERO All]",
#"Pst A",
 "Avg[I 有效值 A]",
 "Avg[I 总谐波畸变率 A]",
 "Avg[I 负序不平衡 Total]",
 "Avg[I SPOS All]",
 "Avg[I SNEG All]",
 "Avg[I ZERO All]",
# "Avg[P A]",
# "Avg[Q A]",
# "Avg[S A]",
# "Avg[功率因数 A]"
 ]

# %%
tr_data=DataFrame()
i=0
for df in dfs:
    for c in df.columns:
        if c.find("Avg[V 总谐波畸变率 A]")!=-1:
            print (c)
            tr_data[c]=df[c]
            i+=1
print(i)
# Out:
#  KunYang3 - Avg[V 总谐波畸变率 A] (%)
#  WanKe1 - Avg[V 总谐波畸变率 A] (%)
#  Changliu3 - Avg[V 总谐波畸变率 A] (%)
#  JiangChuan1 - Avg[V 总谐波畸变率 A] (%)
#  Changliu2 - Avg[V 总谐波畸变率 A] (%)
#  QinZhou4 - Avg[V 总谐波畸变率 A] (%)
#  Changliu1 - Avg[V 总谐波畸变率 A] (%)
#  JiangChuan4 - Avg[V 总谐波畸变率 A] (%)
#  JiangChuan5 - Avg[V 总谐波畸变率 A] (%)
#  QinZhou3 - Avg[V 总谐波畸变率 A] (%)
#  KunYang1 - Avg[V 总谐波畸变率 A] (%)
#  JiangChuan3 - Avg[V 总谐波畸变率 A] (%)
#  JiangChuan2 - Avg[V 总谐波畸变率 A] (%)
#  WanKe2 - Avg[V 总谐波畸变率 A] (%)
# 14

# %%
train_data=tr_data.dropna()

# %%
len(tr_data)
# Out:
# 4032

# %%
train_data=train_data.dropna(axis=1)

# %%
corMat=DataFrame(train_data.corr())
plot.pcolor(corMat)
plot.show()

# %%
from sklearn.model_selection import train_test_split
train,test= train_test_split(train_data,test_size=0.2,random_state=0)

# %%
MAX= train.max()
MIN = train.min()

# %%
train_s=(train-MIN)/(MAX-MIN)
test_s=(test-MIN)/(MAX-MIN)

# %%
train_s=train_s.fillna(0)
test_s=test_s.fillna(0)

# %%
#  generate X_train,Y_train,X_test,Y_test for all target features
X_train=train_s.copy();Y_train=DataFrame()

for c in train_s.columns:
    if c.find("WanKe1") !=-1 :
        Y_train[c]=train_s[c]
        X_train=X_train.drop(c,axis=1)

        
X_test=test_s.copy();Y_test=DataFrame()

for c in test_s.columns:
    if c.find("WanKe1") !=-1 :
        Y_test[c]=test_s[c]
        X_test=X_test.drop(c,axis=1)

# %%
###### network from keras for SHDKY data simulation ###########
from keras.models import Sequential
from keras.layers import Dense, Activation,Input
import keras


model = Sequential()

model.add(Dense(13, input_dim=13,init="normal"))
model.add(Activation('relu'))
model.add(Dense(7, activation='relu',init="normal"))
model.add(Dense(1, activation='linear',init="normal"))
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(13, input_dim=13, kernel_initializer="normal")`
#   if __name__ == '__main__':
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(7, activation="relu", kernel_initializer="normal")`
#   # This is added back by InteractiveShellApp.init_path()
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="linear", kernel_initializer="normal")`
#   if sys.path[0] == '':

# %%
model.compile(loss='mean_squared_error', 
              optimizer=keras.optimizers.SGD(lr=0.01))

# %%
model.fit(X_train, Y_train, epochs=30,batch_size=10,
          shuffle=True,verbose=2,validation_split=0.2)
# Out:
# Train on 2111 samples, validate on 528 samples
# Epoch 1/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 2/30
#  - 0s - loss: 0.0045 - val_loss: 0.0048
# Epoch 3/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 4/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 5/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 6/30
#  - 0s - loss: 0.0045 - val_loss: 0.0049
# Epoch 7/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 8/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 9/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 10/30
#  - 0s - loss: 0.0045 - val_loss: 0.0048
# Epoch 11/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 12/30
#  - 0s - loss: 0.0045 - val_loss: 0.0048
# Epoch 13/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 14/30
#  - 0s - loss: 0.0045 - val_loss: 0.0048
# Epoch 15/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 16/30
#  - 0s - loss: 0.0045 - val_loss: 0.0048
# Epoch 17/30
#  - 0s - loss: 0.0045 - val_loss: 0.0046
# Epoch 18/30
#  - 0s - loss: 0.0045 - val_loss: 0.0046
# Epoch 19/30
#  - 0s - loss: 0.0045 - val_loss: 0.0046
# Epoch 20/30
#  - 0s - loss: 0.0045 - val_loss: 0.0046
# Epoch 21/30
#  - 0s - loss: 0.0045 - val_loss: 0.0046
# Epoch 22/30
#  - 0s - loss: 0.0045 - val_loss: 0.0046
# Epoch 23/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 24/30
#  - 0s - loss: 0.0045 - val_loss: 0.0048
# Epoch 25/30
#  - 0s - loss: 0.0045 - val_loss: 0.0046
# Epoch 26/30
#  - 0s - loss: 0.0045 - val_loss: 0.0048
# Epoch 27/30
#  - 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 28/30
#  - 0s - loss: 0.0045 - val_loss: 0.0046
# Epoch 29/30
#  - 0s - loss: 0.0044 - val_loss: 0.0046
# Epoch 30/30
#  - 0s - loss: 0.0045 - val_loss: 0.0046

# %%
((model.predict(X_test)-Y_test)/Y_test)
# Out:
#                       WanKe1 - Avg[V 总谐波畸变率 A] (%)
# 时间
# 2018-02-02 05:24:00                       0.011770
# 2018-02-01 01:42:00                       0.336365
# 2018-02-02 20:36:00                      -0.003245
# 2018-02-07 13:15:00                       0.176894
# 2018-02-03 09:27:00                      -0.147802
# 2018-02-05 09:48:00                      -0.021790
# 2018-02-06 10:06:00                      -0.064584
# 2018-02-02 05:06:00                      -0.047949
# 2018-02-02 10:24:00                       0.027150
# 2018-02-04 16:12:00                      -0.044744
# 2018-02-02 10:27:00                      -0.013012
# 2018-02-06 12:21:00                      -0.058823
# 2018-02-07 05:48:00                       0.497692
# 2018-02-02 06:57:00                      -0.246806
# 2018-02-01 04:39:00                       0.420013
# 2018-02-07 03:39:00                      -0.155137
# 2018-02-01 14:48:00                      -0.009546
# 2018-02-01 13:12:00                       0.029822
# 2018-02-04 15:57:00                       0.026766
# 2018-02-02 11:21:00                       0.104546
# 2018-02-06 17:24:00                      -0.093991
# 2018-02-02 10:12:00                       0.046080
# 2018-02-04 06:30:00                      -0.175004
# 2018-02-07 21:15:00                       0.025842
# 2018-02-03 16:03:00                      -0.074243
# 2018-02-03 21:18:00                       0.121465
# 2018-02-03 06:15:00                       0.031526
# 2018-02-01 18:06:00                       0.054384
# 2018-02-06 21:33:00                      -0.235390
# 2018-02-07 01:42:00                       0.025492
# ...                                            ...
# 2018-02-06 14:09:00                       0.038885
# 2018-02-01 22:21:00                       0.106197
# 2018-02-02 18:24:00                       0.125154
# 2018-02-07 17:00:00                       0.035541
# 2018-02-05 12:09:00                       0.000068
# 2018-02-02 02:33:00                      -0.105309
# 2018-02-01 12:18:00                       0.021817
# 2018-02-05 18:36:00                       0.004128
# 2018-02-01 12:09:00                      -0.024632
# 2018-02-07 03:33:00                      -0.162116
# 2018-02-04 03:36:00                      -0.201396
# 2018-02-03 16:42:00                      -0.220692
# 2018-02-03 23:24:00                       0.056273
# 2018-02-05 05:00:00                       0.076497
# 2018-02-05 13:27:00                       0.043237
# 2018-02-07 14:18:00                       0.148399
# 2018-02-02 11:51:00                       0.143264
# 2018-02-02 10:39:00                       0.025806
# 2018-02-06 06:03:00                       0.111171
# 2018-02-02 21:45:00                       0.189682
# 2018-02-05 10:42:00                      -0.017983
# 2018-02-07 12:36:00                      -0.012049
# 2018-02-01 02:42:00                       0.322368
# 2018-02-06 18:54:00                       0.018606
# 2018-02-07 06:15:00                       0.685472
# 2018-02-03 08:09:00                       0.063147
# 2018-02-03 03:39:00                       0.064633
# 2018-02-05 06:36:00                      -0.037652
# 2018-02-03 10:36:00                      -0.191767
# 2018-02-07 09:57:00                      -0.090333
#
# [660 rows x 1 columns]

# %%
c=Y_test.columns
R= pd.DataFrame(model.predict(X_test),columns=['V_pred'])
R.index = Y_test.index
R= R.join(Y_test)
R=  R*((MAX[c]-MIN[c])+MIN[c]).values[0]

# %%
R_show=R.iloc[200:300,:]

import pylab
pylab.rcParams['figure.figsize'] = (12.0, 4.0)

R_show.plot(alpha =0.5,figsize = (12,4))

# %%
R_show
# Out:
#                        V_pred   WanKe1 - Avg[V 总谐波畸变率 A] (%)
# 时间
# 2018-02-07 09:36:00  1.339528                       1.398077
# 2018-02-03 00:30:00  0.524243                       0.552737
# 2018-02-06 01:51:00  0.680688                       0.688319
# 2018-02-03 10:45:00  1.219696                       1.307293
# 2018-02-02 00:18:00  0.247047                       0.265606
# 2018-02-01 01:33:00  0.651675                       0.374257
# 2018-02-04 12:42:00  1.264702                       1.266713
# 2018-02-01 20:00:00  0.585493                       0.596372
