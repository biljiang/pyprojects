# %%
import numpy as np
import pandas as pd
import pathlib as pl
from datetime import datetime
import matplotlib.pyplot as plot
from pandas import DataFrame, Series

# read .xlsx files under ./data directory into datatables.

# %%
# read from csv files

datapath=pl.Path("./6-8月数据")

file_list=[]
dfs=[]
for x in datapath.glob("*.csv"):
    print("Reading "+x.name)
    f=pd.read_csv(x,index_col=0,na_values=" ")
    dfs.append(f)
    file_list.append(x.name)
# Out:
# Reading ChangLiu3.csv
# Reading HaiLu6.csv
# Reading ChangLiu2.csv
# Reading WanKe1.csv
# Reading HaiLu4.csv
# Reading HaiLu3.csv
# Reading WanKe2.csv
# Reading HaiLu1.csv
# Reading HaiLu2.csv
# Reading HaiLu5.csv
# Reading ChangLiu4.csv
# Reading ChangLiu1.csv

# %%
# read from csv files

datapath=pl.Path("./data_Jun_Aug")

for x in datapath.glob("*.csv"):
    print("Reading "+x.name)
    f=pd.read_csv(x,index_col=0,na_values=" ")
    dfs.append(f)
    file_list.append(x.name)
# Out:
# Reading KunYang3.csv
# Reading JiangChuan3.csv
# Reading KunYang1.csv

# %%
# write to csv file
'''
import re
for x,y in zip(dfs,file_list):
    rx=re.compile("[A-Za-z]{4,}[0-9]")
    x.to_csv("./6-8月数据/"+rx.findall(y)[-1]+".csv",index=False)
'''

# %%
cols = ["Avg[V 有效值 AB]",
# "Avg[V 总谐波畸变率 A]",
 "Avg[V 负序不平衡 Total]",
 "Avg[V SPOS All]",
 "Avg[V SNEG All]",
 "Avg[V SZERO All]",
#"Pst A",
 "Avg[I 有效值 A]",
 "Avg[I 总谐波畸变率 A]",
 "Avg[I 负序不平衡 Total]",
 "Avg[I SPOS All]",
 "Avg[I SNEG All]",
 "Avg[I ZERO All]",
# "Avg[P A]",
# "Avg[Q A]",
# "Avg[S A]",
# "Avg[功率因数 A]"
 ]

# %%
tr_data=DataFrame()
i=0
for df in dfs:
    for c in df.columns:
        if c.find("Avg[V 有效值 A]")!=-1:
            print (c)
            tr_data[c]=df[c]
            i+=1
print(i)
# Out:
#  Changliu3 - Avg[V 有效值 A] (V)
#  Changliu2 - Avg[V 有效值 A] (V)
#  WanKe1 - Avg[V 有效值 A] (V)
#  WanKe2 - Avg[V 有效值 A] (V)
#  Changliu4 - Avg[V 有效值 A] (V)
#  Changliu1 - Avg[V 有效值 A] (V)
#  KunYang3 - Avg[V 有效值 A] (V)
#  JiangChuan3 - Avg[V 有效值 A] (V)
#  KunYang1 - Avg[V 有效值 A] (V)
# 9

# %%
len(train_data)
# Out:
# 42652

# %%
#tr_data.dropna().to_csv('train_data')

# %%
train_data=tr_data.dropna()

# %%
corMat=DataFrame(train_data.corr())
plot.pcolor(corMat)
plot.show()

# %%
from sklearn.model_selection import train_test_split
train,test= train_test_split(train_data,test_size=0.2,random_state=0)

# %%
M= train.mean()
Std = train.std()

# %%
train_s=(train-M)/Std
test_s=(test-M)/Std

# %%
#  generate X_train,Y_train,X_test,Y_test for all target features
X_train=train_s.copy();Y_train=DataFrame()

for c in train_s.columns:
    if c.find("KunYang1") !=-1 :
        Y_train[c]=train_s[c]
        X_train=X_train.drop(c,axis=1)

        
X_test=test_s.copy();Y_test=DataFrame()

for c in test_s.columns:
    if c.find("KunYang1") !=-1 :
        Y_test[c]=test_s[c]
        X_test=X_test.drop(c,axis=1)

# %%
###### network from keras for SHDKY data simulation ###########
from keras.models import Sequential
from keras.layers import Dense, Activation,Input
import keras


model = Sequential()

model.add(Dense(8, input_dim=8,init="normal"))
model.add(Activation('tanh'))
model.add(Dense(6, activation='tanh',init="normal"))
model.add(Dense(1, activation='linear',init="normal"))
# Out:
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(8, input_dim=8, kernel_initializer="normal")`
#   if __name__ == '__main__':
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(6, activation="tanh", kernel_initializer="normal")`
#   # This is added back by InteractiveShellApp.init_path()
# /home/techstar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="linear", kernel_initializer="normal")`
#   if sys.path[0] == '':

# %%
model.compile(loss='mean_squared_error', 
              optimizer=keras.optimizers.SGD(lr=0.2))

# %%
model.fit(X_train, Y_train, epochs=30,batch_size=10,
          shuffle=True,verbose=2,validation_split=0.2)
# Out:
# Train on 27296 samples, validate on 6825 samples
# Epoch 1/30
#  - 2s - loss: 0.3622 - val_loss: 0.3128
# Epoch 2/30
#  - 2s - loss: 0.3575 - val_loss: 0.2762
# Epoch 3/30
#  - 2s - loss: 0.3573 - val_loss: 0.3344
# Epoch 4/30
#  - 2s - loss: 0.3717 - val_loss: 0.2935
# Epoch 5/30
#  - 2s - loss: 0.3713 - val_loss: 0.3374
# Epoch 6/30
#  - 2s - loss: 0.3669 - val_loss: 0.3008
# Epoch 7/30
#  - 2s - loss: 0.3647 - val_loss: 0.2927
# Epoch 8/30
#  - 2s - loss: 0.3719 - val_loss: 0.2962
# Epoch 9/30
#  - 2s - loss: 0.3742 - val_loss: 0.2994
# Epoch 10/30
#  - 2s - loss: 0.3636 - val_loss: 0.2783
# Epoch 11/30
#  - 2s - loss: 0.3586 - val_loss: 0.3039
# Epoch 12/30
#  - 2s - loss: 0.3591 - val_loss: 0.3455
# Epoch 13/30
#  - 2s - loss: 0.3620 - val_loss: 0.2980
# Epoch 14/30
#  - 2s - loss: 0.3582 - val_loss: 0.2877
# Epoch 15/30
#  - 2s - loss: 0.3581 - val_loss: 0.2877
# Epoch 16/30
#  - 2s - loss: 0.3658 - val_loss: 0.4490
# Epoch 17/30
#  - 2s - loss: 0.3646 - val_loss: 0.3702
# Epoch 18/30
#  - 2s - loss: 0.3529 - val_loss: 0.3577
# Epoch 19/30
#  - 2s - loss: 0.3622 - val_loss: 0.4624
# Epoch 20/30
#  - 2s - loss: 0.3593 - val_loss: 0.3183
# Epoch 21/30
#  - 2s - loss: 0.3563 - val_loss: 0.2710
# Epoch 22/30
#  - 2s - loss: 0.3510 - val_loss: 0.2764
# Epoch 23/30
#  - 2s - loss: 0.3518 - val_loss: 0.2894
# Epoch 24/30
#  - 2s - loss: 0.3560 - val_loss: 0.3277
# Epoch 25/30
#  - 2s - loss: 0.3602 - val_loss: 0.3255
# Epoch 26/30
#  - 2s - loss: 0.3773 - val_loss: 0.2840
# Epoch 27/30
#  - 2s - loss: 0.3598 - val_loss: 0.2829
# Epoch 28/30
#  - 2s - loss: 0.3573 - val_loss: 0.3034
# Epoch 29/30
#  - 2s - loss: 0.3664 - val_loss: 0.3217
# Epoch 30/30
#  - 2s - loss: 0.3700 - val_loss: 0.3652

# %%
(model.predict(X_test)-Y_test)/Y_test
# Out:
#                       WanKe1 - Avg[V 有效值 AB] (V)
# 时间
# 2017-06-06 00:15:00                    -0.071295
# 2017-06-26 20:15:00                    -1.543686
# 2017-06-21 21:45:00                    -0.014884
# 2017-06-04 10:45:00                    -1.493933
# 2017-06-09 07:00:00                    -2.434166
# 2017-06-01 08:30:00                    -0.341035
# 2017-06-05 15:00:00                    -0.467598
# 2017-06-27 06:15:00                     0.099491
# 2017-06-19 04:00:00                    -0.145898
# 2017-06-24 09:00:00                    -0.415939
# 2017-06-29 21:30:00                    -4.567393
# 2017-06-05 17:45:00                    -1.692664
# 2017-06-29 19:00:00                    -0.309267
# 2017-06-10 07:00:00                     0.471409
# 2017-06-26 09:15:00                    -0.198155
# 2017-06-29 09:45:00                     0.021292
# 2017-06-12 15:15:00                     2.259688
# 2017-06-01 13:30:00                     0.216315
# 2017-06-20 08:00:00                     0.802493
# 2017-06-07 17:45:00                    -1.352367
# 2017-06-28 18:00:00                    -0.409084
# 2017-06-05 01:45:00                     0.172251
# 2017-06-19 19:15:00                     0.051147
# 2017-06-07 11:00:00                     4.424700
# 2017-06-05 09:45:00                    -0.926156
# 2017-06-27 03:00:00                     0.125376
# 2017-06-12 01:30:00                    -2.185953
# 2017-06-07 23:45:00                     0.126584
# 2017-06-10 08:15:00                    -0.272613
# 2017-06-15 02:30:00                    -0.752804
# ...                                          ...
# 2017-06-05 17:30:00                    -1.187449
# 2017-06-27 03:45:00                    -0.708054
# 2017-06-30 11:30:00                    -1.125482
# 2017-06-23 10:15:00                    -0.124045
# 2017-06-12 00:15:00                    -1.967766
# 2017-06-22 09:45:00                    -0.026041
# 2017-06-04 02:15:00                    -0.420068
# 2017-06-06 14:15:00                     1.163398
# 2017-06-28 17:45:00                    -0.887163
# 2017-06-06 16:00:00                     0.410583
# 2017-06-13 05:30:00                    -0.454767
# 2017-06-28 12:00:00                    -0.520997
# 2017-06-10 15:45:00                     1.039970
# 2017-06-27 16:15:00                    -0.514329
# 2017-06-22 03:15:00                     0.312270
# 2017-06-21 05:45:00                    -0.300028
# 2017-06-15 15:15:00                     0.852115
# 2017-06-12 01:00:00                     0.555631
# 2017-06-29 00:45:00                    -8.159984
# 2017-06-22 02:30:00                    -0.337916
# 2017-06-21 15:30:00                     0.278574
# 2017-06-19 14:45:00                    -0.199925
# 2017-06-28 20:30:00                     0.163747
# 2017-06-29 19:45:00                    -1.257984
# 2017-06-22 13:00:00                     0.119309
# 2017-06-19 11:00:00                     0.266019
# 2017-06-01 13:15:00                     0.262968
# 2017-06-13 00:00:00                    -1.543919
# 2017-06-08 07:45:00                    -0.015773
# 2017-06-14 16:15:00                     0.209553
#
# [506 rows x 1 columns]

# %%
Y_train
# Out:
#                       Changliu3 - Avg[V 有效值 A] (V)
# 时间
# 2017-06-21 03:39:00                       1.242976
# 2017-08-09 14:00:00                      -1.581354
# 2017-08-01 04:51:00                       0.896351
# 2017-07-17 17:06:00                      -0.402780
# 2017-08-31 14:12:00                      -0.570351
# 2017-06-29 18:51:00                      -0.214738
# 2017-07-11 00:57:00                       0.930508
# 2017-06-04 09:24:00                      -0.299067
# 2017-07-19 19:45:00                      -1.199888
# 2017-08-15 05:09:00                       0.972376
# 2017-06-08 18:36:00                       0.054445
# 2017-07-02 08:36:00                      -0.461688
# 2017-07-30 00:48:00                       0.348264
# 2017-07-09 09:06:00                      -1.206269
# 2017-07-30 20:21:00                      -0.491617
# 2017-08-13 23:30:00                      -0.265125
# 2017-06-27 21:57:00                       0.805602
# 2017-07-28 03:21:00                       1.022308
# 2017-07-29 15:54:00                      -1.761839
# 2017-06-23 16:12:00                      -0.763762
# 2017-08-14 03:54:00                       0.999697
# 2017-07-06 06:09:00                       0.276265
# 2017-08-07 14:24:00                      -0.317653
# 2017-08-09 20:06:00                      -0.575808
# 2017-08-11 00:09:00                       0.120936
# 2017-08-09 23:51:00                       0.355923
# 2017-08-24 19:33:00                       0.773040
# 2017-07-23 16:48:00                      -0.332579
# 2017-06-03 11:12:00                      -0.561337
# 2017-06-07 15:21:00                      -0.805996
# ...                                            ...
# 2017-07-25 09:03:00                      -0.934637
# 2017-06-06 04:51:00                       1.442109
# 2017-06-19 18:12:00                      -0.115190
# 2017-06-04 21:36:00                       0.549638
# 2017-07-12 08:48:00                      -0.432608
# 2017-06-20 08:06:00                      -0.604382
# 2017-08-21 12:24:00                      -1.674559
# 2017-06-11 14:42:00                      -0.053256
# 2017-06-05 12:12:00                      -0.261049
# 2017-08-23 23:39:00                       0.214356
# 2017-06-15 12:15:00                      -0.444660
# 2017-08-24 08:39:00                      -1.706146
# 2017-07-31 04:45:00                       0.909961
# 2017-07-09 05:21:00                       0.744681
# 2017-08-17 10:42:00                      -0.186417
# 2017-07-24 06:54:00                      -0.521192
# 2017-07-13 12:27:00                      -1.839763
# 2017-08-10 06:57:00                      -0.566705
# 2017-07-09 13:45:00                      -1.379012
# 2017-07-04 11:48:00                      -0.061308
# 2017-08-25 11:03:00                      -0.191076
# 2017-07-06 02:48:00                       0.850065
# 2017-07-05 02:03:00                       1.098155
# 2017-07-17 05:09:00                       0.977212
# 2017-08-30 15:06:00                      -0.414795
# 2017-08-10 00:36:00                       0.690483
# 2017-08-06 08:36:00                      -0.542638
# 2017-07-18 05:27:00                       0.754354
# 2017-08-31 22:06:00                       0.914468
# 2017-06-06 16:39:00                      -0.286154
#
# [34121 rows x 1 columns]

# %%
M
# Out:
#  Changliu3 - Avg[V 有效值 A] (V)      66239.215310
#  Changliu2 - Avg[V 有效值 A] (V)      66385.198319
#  WanKe1 - Avg[V 有效值 A] (V)            92.993566
#  WanKe2 - Avg[V 有效值 A] (V)          5967.349035
#  Changliu4 - Avg[V 有效值 A] (V)      66246.276386
#  Changliu1 - Avg[V 有效值 A] (V)      66413.393866
#  KunYang3 - Avg[V 有效值 A] (V)        9898.420824
#  JiangChuan3 - Avg[V 有效值 A] (V)    64202.018849
#  KunYang1 - Avg[V 有效值 A] (V)       20914.002418
# dtype: float64

# %%
Std
# Out:
#  Changliu3 - Avg[V 有效值 A] (V)       617.089011
#  Changliu2 - Avg[V 有效值 A] (V)       527.710888
#  WanKe1 - Avg[V 有效值 A] (V)            0.986196
#  WanKe2 - Avg[V 有效值 A] (V)           69.208721
#  Changliu4 - Avg[V 有效值 A] (V)       617.415263
#  Changliu1 - Avg[V 有效值 A] (V)       527.783519
#  KunYang3 - Avg[V 有效值 A] (V)       6578.474288
#  JiangChuan3 - Avg[V 有效值 A] (V)     810.844800
#  KunYang1 - Avg[V 有效值 A] (V)        233.289743
# dtype: float64

# %%
train.max()
# Out:
#  Changliu3 - Avg[V 有效值 A] (V)      67534.031250
#  Changliu2 - Avg[V 有效值 A] (V)      68145.773438
#  WanKe1 - Avg[V 有效值 A] (V)            95.808167
#  WanKe2 - Avg[V 有效值 A] (V)          6113.998535
#  Changliu4 - Avg[V 有效值 A] (V)      67542.132812
#  Changliu1 - Avg[V 有效值 A] (V)      68175.429688
#  KunYang3 - Avg[V 有效值 A] (V)       21404.712891
#  JiangChuan3 - Avg[V 有效值 A] (V)    67347.367188
#  KunYang1 - Avg[V 有效值 A] (V)       21429.019531
# dtype: float64

# %%
train.min()
# Out:
#  Changliu3 - Avg[V 有效值 A] (V)      64784.941406
#  Changliu2 - Avg[V 有效值 A] (V)      65110.730469
#  WanKe1 - Avg[V 有效值 A] (V)            89.247429
#  WanKe2 - Avg[V 有效值 A] (V)          5797.876465
#  Changliu4 - Avg[V 有效值 A] (V)      64791.621094
#  Changliu1 - Avg[V 有效值 A] (V)      65138.785156
#  KunYang3 - Avg[V 有效值 A] (V)        4583.943359
#  JiangChuan3 - Avg[V 有效值 A] (V)    61840.878906
#  KunYang1 - Avg[V 有效值 A] (V)       14768.707031
# dtype: float64

# %%
train.median()
# Out:
#  Changliu3 - Avg[V 有效值 A] (V)      66268.335938
#  Changliu2 - Avg[V 有效值 A] (V)      66386.093750
#  WanKe1 - Avg[V 有效值 A] (V)            92.938095
#  WanKe2 - Avg[V 有效值 A] (V)          5964.761230
#  Changliu4 - Avg[V 有效值 A] (V)      66275.476562
#  Changliu1 - Avg[V 有效值 A] (V)      66414.250000
#  KunYang3 - Avg[V 有效值 A] (V)        6013.958008
#  JiangChuan3 - Avg[V 有效值 A] (V)    64203.542969
#  KunYang1 - Avg[V 有效值 A] (V)       20923.894531
# dtype: float64
